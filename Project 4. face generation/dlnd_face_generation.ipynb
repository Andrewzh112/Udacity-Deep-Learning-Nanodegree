# %% [markdown]
# # Face Generation
#
# In this project, you'll define and train a DCGAN on a dataset of faces. Your goal is to get a generator network to generate *new* images of faces that look as realistic as possible!
#
# The project will be broken down into a series of tasks from **loading in data to defining and training adversarial networks**. At the end of the notebook, you'll be able to visualize the results of your trained Generator to see how it performs; your generated samples should look like fairly realistic faces with small amounts of noise.
#
# ### Get the Data
#
# You'll be using the [CelebFaces Attributes Dataset (CelebA)](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) to train your adversarial networks.
#
# This dataset is more complex than the number datasets (like MNIST or SVHN) you've been working with, and so, you should prepare to define deeper networks and train them for a longer time to get good results. It is suggested that you utilize a GPU for training.
#
# ### Pre-processed Data
#
# Since the project's main focus is on building the GANs, we've done *some* of the pre-processing for you. Each of the CelebA images has been cropped to remove parts of the image that don't include a face, then resized down to 64x64x3 NumPy images. Some sample data is show below.
#
# <img src='assets/processed_face_data.png' width=60% />
#
# > If you are working locally, you can download this data [by clicking here](https://s3.amazonaws.com/video.udacity-data.com/topher/2018/November/5be7eb6f_processed-celeba-small/processed-celeba-small.zip)
#
# This is a zip file that you'll need to extract in the home directory of this notebook for further loading and processing. After extracting the data, you should be left with a directory of data `processed_celeba_small/`

# %%
# can comment out after executing
# !unzip processed_celeba_small.zip

# %%
data_dir = 'processed_celeba_small/'

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle as pkl
import matplotlib.pyplot as plt
import numpy as np
import problem_unittests as tests
#import helper

# %matplotlib inline

# %% [markdown]
# ## Visualize the CelebA Data
#
# The [CelebA](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) dataset contains over 200,000 celebrity images with annotations. Since you're going to be generating faces, you won't need the annotations, you'll only need the images. Note that these are color images with [3 color channels (RGB)](https://en.wikipedia.org/wiki/Channel_(digital_image)#RGB_Images) each.
#
# ### Pre-process and Load the Data
#
# Since the project's main focus is on building the GANs, we've done *some* of the pre-processing for you. Each of the CelebA images has been cropped to remove parts of the image that don't include a face, then resized down to 64x64x3 NumPy images. This *pre-processed* dataset is a smaller subset of the very large CelebA data.
#
# > There are a few other steps that you'll need to **transform** this data and create a **DataLoader**.
#
# #### Exercise: Complete the following `get_dataloader` function, such that it satisfies these requirements:
#
# * Your images should be square, Tensor images of size `image_size x image_size` in the x and y dimension.
# * Your function should return a DataLoader that shuffles and batches these Tensor images.
#
# #### ImageFolder
#
# To create a dataset given a directory of images, it's recommended that you use PyTorch's [ImageFolder](https://pytorch.org/docs/stable/torchvision/datasets.html#imagefolder) wrapper, with a root directory `processed_celeba_small/` and data transformation passed in.

# %%
# necessary imports
import torch
from torchvision import datasets
from torchvision import transforms

# %%
def get_dataloader(batch_size, image_size, data_dir='processed_celeba_small/'):
    """
    Batch the neural network data using DataLoader
    :param batch_size: The size of each batch; the number of images in a batch
    :param img_size: The square size of the image data (x, y)
    :param data_dir: Directory where image data is located
    :return: DataLoader with batched data
    """
    
    # TODO: Implement function and return a dataloader
    transform = transforms.Compose([
        transforms.Resize(image_size),
#         transforms.CenterCrop(image_size),
        transforms.ToTensor()
    ])
    img_dataset = datasets.ImageFolder(data_dir,transform=transform)
    img_dataloader = torch.utils.data.DataLoader(img_dataset, batch_size=batch_size, shuffle=True)
    return img_dataloader

# %% [markdown]
# ## Create a DataLoader
#
# #### Exercise: Create a DataLoader `celeba_train_loader` with appropriate hyperparameters.
#
# Call the above function and create a dataloader to view images.
# * You can decide on any reasonable `batch_size` parameter
# * Your `image_size` **must be** `32`. Resizing the data to a smaller size will make for faster training, while still creating convincing images of faces!

# %%
# Define function hyperparameters
batch_size = 16
img_size = 32

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# Call your function and get a dataloader
celeba_train_loader = get_dataloader(batch_size, img_size)

# %% [markdown]
# Next, you can view some images! You should seen square images of somewhat-centered faces.
#
# Note: You'll need to convert the Tensor images into a NumPy type and transpose the dimensions to correctly display an image, suggested `imshow` code is below, but it may not be perfect.

# %%
# helper display function
def imshow(img):
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# obtain one batch of training images
dataiter = iter(celeba_train_loader)
images, _ = dataiter.next() # _ for no labels

# plot the images in the batch, along with the corresponding labels
fig = plt.figure(figsize=(20, 4))
plot_size=20
for idx in np.arange(plot_size):
    ax = fig.add_subplot(2, plot_size/2, idx+1, xticks=[], yticks=[])
    imshow(images[idx])

# %% [markdown]
# #### Exercise: Pre-process your image data and scale it to a pixel range of -1 to 1
#
# You need to do a bit of pre-processing; you know that the output of a `tanh` activated generator will contain pixel values in a range from -1 to 1, and so, we need to rescale our training images to a range of -1 to 1. (Right now, they are in a range from 0-1.)

# %%
# TODO: Complete the scale function
def scale(x, feature_range=(-1, 1)):
    ''' Scale takes in an image x and returns that image, scaled
       with a feature_range of pixel values from -1 to 1. 
       This function assumes that the input x is already scaled from 0-1.'''
    # assume x is scaled to (0, 1)
    # scale to feature_range and return scaled x
    min,max = feature_range
    x = x*(max-min)-max
    return x

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# check scaled range
# should be close to -1 to 1
img = images[0]
scaled_img = scale(img)

print('Min: ', scaled_img.min())
print('Max: ', scaled_img.max())
# Out:
# Min:  tensor(-0.9059)
# Max:  tensor(0.7725)

# %% [markdown]
# ---
# # Define the Model
#
# A GAN is comprised of two adversarial networks, a discriminator and a generator.
#
# ## Discriminator
#
# Your first task will be to define the discriminator. This is a convolutional classifier like you've built before, only without any maxpooling layers. To deal with this complex data, it's suggested you use a deep network with **normalization**. You are also allowed to create any helper functions that may be useful.
#
# #### Exercise: Complete the Discriminator class
# * The inputs to the discriminator are 32x32x3 tensor images
# * The output should be a single value that will indicate whether a given image is real or fake

# %%
import torch.nn as nn
import torch.nn.functional as F

# %%
def conv(in_channels, out_channels, kernel_size, stride=2, padding=1, batch_norm=True):
    """Creates a convolutional layer, with optional batch normalization.
    """
    layers = []
    conv_layer = nn.Conv2d(in_channels, out_channels, 
                           kernel_size, stride, padding, bias=False)

    layers.append(conv_layer)

    if batch_norm:
        layers.append(nn.BatchNorm2d(out_channels))
     
    return nn.Sequential(*layers)

# %%
class Discriminator(nn.Module):

    def __init__(self, conv_dim):
        """
        Initialize the Discriminator Module
        :param conv_dim: The depth of the first convolutional layer
        """
        super(Discriminator, self).__init__()

        # complete init function
        
        self.conv_dim = conv_dim
        # (32x32x3) -> (16x16xconv_dim)
        self.convbn1 = conv(3,conv_dim,4,batch_norm=False)
        # (16x16xconv_dim) -> (8x8xconv_dim*2)
        self.convbn2 = conv(conv_dim,conv_dim*2,4)
        # (8x8xconv_dim*2) -> (4x4xconv_dim*4)
        self.convbn3 = conv(conv_dim*2,conv_dim*4,4)
        
        self.fc = nn.Linear(4*4*conv_dim*4,1)
        
        self.drop = nn.Dropout(0.1)
#         self.drop2d = nn.Dropout2d(0.1)
        

    def forward(self, x):
        """
        Forward propagation of the neural network
        :param x: The input to the neural network     
        :return: Discriminator logits; the output of the neural network
        """
        # define feedforward behavior
        x = F.leaky_relu(self.convbn1(x), 0.2)
        x = self.drop(x)
        x = F.leaky_relu(self.convbn2(x), 0.2)
        x = self.drop(x)
        x = F.leaky_relu(self.convbn3(x), 0.2)
        
        x = x.view(-1,4*4*self.conv_dim*4)
        x = self.drop(x)
        x = self.fc(x)
        return x


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_discriminator(Discriminator)
# Out:
# Tests Passed

# %% [markdown]
# ## Generator
#
# The generator should upsample an input and generate a *new* image of the same size as our training data `32x32x3`. This should be mostly transpose convolutional layers with normalization applied to the outputs.
#
# #### Exercise: Complete the Generator class
# * The inputs to the generator are vectors of some length `z_size`
# * The output should be a image of shape `32x32x3`

# %%
def deconv(in_channels, out_channels, kernel_size, stride=2, padding=1, batch_norm=True):
    """Creates a transposed-convolutional layer, with optional batch normalization.
    """
    layers = []
    conv_layer = nn.ConvTranspose2d(in_channels, out_channels, 
                           kernel_size, stride, padding, bias=False)
    
    layers.append(conv_layer)

    if batch_norm:
        layers.append(nn.BatchNorm2d(out_channels))
    return nn.Sequential(*layers)

# %%
class Generator(nn.Module):
    
    def __init__(self, z_size, conv_dim):
        """
        Initialize the Generator Module
        :param z_size: The length of the input latent vector, z
        :param conv_dim: The depth of the inputs to the *last* transpose convolutional layer
        """
        super(Generator, self).__init__()

        # complete init function
        self.conv_dim = conv_dim
        
        self.deconv1 = deconv(conv_dim*4,conv_dim*2,4)
        self.deconv2 = deconv(conv_dim*2,conv_dim,4)
        self.deconv3 = deconv(conv_dim,3,4,batch_norm=False)
        
        self.drop = nn.Dropout(0.1)
        
        self.fc = nn.Linear(z_size,conv_dim*4*4*4)

    def forward(self, x):
        """
        Forward propagation of the neural network
        :param x: The input to the neural network     
        :return: A 32x32x3 Tensor image as output
        """
        # define feedforward behavior
        x = self.fc(x)
        x = x.view(-1,self.conv_dim*4,4,4)
        
        x = F.relu(self.deconv1(x))
        x = self.drop(x)
        x = F.relu(self.deconv2(x))
        x = self.drop(x)
        x = F.tanh(self.deconv3(x))
        return x

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_generator(Generator)
# Out:
# Tests Passed

# %% [markdown]
# ## Initialize the weights of your networks
#
# To help your models converge, you should initialize the weights of the convolutional and linear layers in your model. From reading the [original DCGAN paper](https://arxiv.org/pdf/1511.06434.pdf), they say:
# > All weights were initialized from a zero-centered Normal distribution with standard deviation 0.02.
#
# So, your next task will be to define a weight initialization function that does just this!
#
# You can refer back to the lesson on weight initialization or even consult existing model code, such as that from [the `networks.py` file in CycleGAN Github repository](https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix/blob/master/models/networks.py) to help you complete this function.
#
# #### Exercise: Complete the weight initialization function
#
# * This should initialize only **convolutional** and **linear** layers
# * Initialize the weights to a normal distribution, centered around 0, with a standard deviation of 0.02.
# * The bias terms, if they exist, may be left alone or set to 0.

# %%
def weights_init_normal(m):
    """
    Applies initial weights to certain layers in a model .
    The weights are taken from a normal distribution 
    with mean = 0, std dev = 0.02.
    :param m: A module or layer in a network    
    """
    # classname will be something like:
    # `Conv`, `BatchNorm2d`, `Linear`, etc.
    classname = m.__class__.__name__
    
    # TODO: Apply initial weights to convolutional and linear layers
    if classname.find('Linear') != -1 or classname.find('Conv') != -1:
        m.weight.data.normal_(0, 0.02)
    if hasattr(m, 'bias') and m.bias is not None:
        m.bias.data.fill_(0)

# %% [markdown]
# ## Build complete network
#
# Define your models' hyperparameters and instantiate the discriminator and generator from the classes defined above. Make sure you've passed in the correct input arguments.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
def build_network(d_conv_dim, g_conv_dim, z_size):
    # define discriminator and generator
    D = Discriminator(d_conv_dim)
    G = Generator(z_size=z_size, conv_dim=g_conv_dim)

    # initialize model weights
    D.apply(weights_init_normal)
    G.apply(weights_init_normal)
    
    print(D)
    print()
    print(G)
    
    return D, G

# %% [markdown]
# #### Exercise: Define model hyperparameters

# %%
# Define model hyperparams
d_conv_dim = 64
g_conv_dim = 64
z_size = 100

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
D, G = build_network(d_conv_dim, g_conv_dim, z_size)
# Out:
# Discriminator(
#   (convbn1): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
#   (convbn2): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (convbn3): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (fc): Linear(in_features=4096, out_features=1, bias=True)
#   (drop): Dropout(p=0.1)
# )
#
# Generator(
#   (deconv1): Sequential(
#     (0): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (deconv2): Sequential(
#     (0): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (deconv3): Sequential(
#     (0): ConvTranspose2d(64, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
#   (drop): Dropout(p=0.1)
#   (fc): Linear(in_features=100, out_features=4096, bias=True)
# )

# %% [markdown]
# ### Training on GPU
#
# Check if you can train on GPU. Here, we'll set this as a boolean variable `train_on_gpu`. Later, you'll be responsible for making sure that
# >* Models,
# * Model inputs, and
# * Loss function arguments
#
# Are moved to GPU, where appropriate.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import torch

# Check for a GPU
train_on_gpu = torch.cuda.is_available()
if not train_on_gpu:
    print('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Training on GPU!')
# Out:
# Training on GPU!

# %% [markdown]
# ---
# ## Discriminator and Generator Losses
#
# Now we need to calculate the losses for both types of adversarial networks.
#
# ### Discriminator Losses
#
# > * For the discriminator, the total loss is the sum of the losses for real and fake images, `d_loss = d_real_loss + d_fake_loss`.
# * Remember that we want the discriminator to output 1 for real images and 0 for fake images, so we need to set up the losses to reflect that.
#
#
# ### Generator Loss
#
# The generator loss will look similar only with flipped labels. The generator's goal is to get the discriminator to *think* its generated images are *real*.
#
# #### Exercise: Complete real and fake loss functions
#
# **You may choose to use either cross entropy or a least squares error loss to complete the following `real_loss` and `fake_loss` functions.**

# %%
def real_loss(D_out, smooth=False):
    '''Calculates how close discriminator outputs are to being real.
       param, D_out: discriminator logits
       return: real loss'''
    p = 1
    if smooth:
        p = 0.9
    criterion = nn.BCEWithLogitsLoss()
    labels = torch.ones_like(D_out) * p
    loss = criterion(D_out,labels)
    return loss

def fake_loss(D_out):
    '''Calculates how close discriminator outputs are to being fake.
       param, D_out: discriminator logits
       return: fake loss'''
    criterion = nn.BCEWithLogitsLoss()
    labels = torch.zeros_like(D_out)
    loss = criterion(D_out,labels)
    return loss

# %% [markdown]
# ## Optimizers
#
# #### Exercise: Define optimizers for your Discriminator (D) and Generator (G)
#
# Define optimizers for your models with appropriate hyperparameters.

# %%
import torch.optim as optim

# Create optimizers for the discriminator D and generator G
lr = 0.0001
beta1 = 0.2
beta2 = 0.999

d_optimizer = optim.Adam(D.parameters(), lr, [beta1, beta2])
g_optimizer = optim.Adam(G.parameters(), lr, [beta1, beta2])

# %% [markdown]
# ---
# ## Training
#
# Training will involve alternating between training the discriminator and the generator. You'll use your functions `real_loss` and `fake_loss` to help you calculate the discriminator losses.
#
# * You should train the discriminator by alternating on real and fake images
# * Then the generator, which tries to trick the discriminator and should have an opposing loss function
#
#
# #### Saving Samples
#
# You've been given some code to print out some loss statistics and save some generated "fake" samples.

# %% [markdown]
# #### Exercise: Complete the training function
#
# Keep in mind that, if you've moved your models to GPU, you'll also have to move any model inputs to GPU.

# %%
def train(D, G, n_epochs, print_every=50):
    '''Trains adversarial networks for some number of epochs
       param, D: the discriminator network
       param, G: the generator network
       param, n_epochs: number of epochs to train for
       param, print_every: when to print and record the models' losses
       return: D and G losses'''
    
    # move models to GPU
    if train_on_gpu:
        D.cuda()
        G.cuda()

    # keep track of loss and generated, "fake" samples
    samples = []
    losses = []

    # Get some fixed data for sampling. These are images that are held
    # constant throughout training, and allow us to inspect the model's performance
    sample_size=16
    fixed_z = np.random.uniform(-1, 1, size=(sample_size, z_size))
    fixed_z = torch.from_numpy(fixed_z).float()
    # move z to GPU if available
    if train_on_gpu:
        fixed_z = fixed_z.cuda()

    # epoch training loop
    for epoch in range(n_epochs):

        # batch training loop
        for batch_i, (real_images, _) in enumerate(celeba_train_loader):

            batch_size = real_images.size(0)
            real_images = scale(real_images)
            if train_on_gpu:
                real_images = real_images.cuda()

            # ===============================================
            #         YOUR CODE HERE: TRAIN THE NETWORKS
            # ===============================================
            
            # 1. Train the discriminator on real and fake images
            d_optimizer.zero_grad()
            
            # discriminator loss on real images
            d_real = D(real_images)
            d_loss_real = real_loss(d_real, smooth=True)
            
            # discriminator loss on fake images
            fake_images = G(fixed_z)
            d_fake = D(fake_images)
            d_loss_fake = fake_loss(d_fake)
            
            # combined loss and backprop
            d_loss = d_loss_real + d_loss_fake
            d_loss.backward()
            d_optimizer.step()
            
            # 2. Train the generator with an adversarial loss
            g_optimizer.zero_grad()
            
            # generate fake images
            fake_images = G(fixed_z)
            
            # calc loss for generator
            d_fake = D(fake_images)
            g_loss = real_loss(d_fake)
            
            # backprop
            g_loss.backward()
            g_optimizer.step()
            
            
            # ===============================================
            #              END OF YOUR CODE
            # ===============================================

            # Print some loss stats
            if batch_i % print_every == 0:
                # append discriminator loss and generator loss
                losses.append((d_loss.item(), g_loss.item()))
                # print discriminator and generator loss
                print('Epoch [{:5d}/{:5d}] | d_loss: {:6.4f} | g_loss: {:6.4f}'.format(
                        epoch+1, n_epochs, d_loss.item(), g_loss.item()))


        ## AFTER EACH EPOCH##    
        # this code assumes your generator is named G, feel free to change the name
        # generate and save sample, fake images
        G.eval() # for generating samples
        samples_z = G(fixed_z)
        samples.append(samples_z)
        G.train() # back to training mode

    # Save training generator samples
    with open('train_samples.pkl', 'wb') as f:
        pkl.dump(samples, f)
    
    # finally return losses
    return losses

# %% [markdown]
# Set your number of training epochs and train your GAN!

# %%
# set number of epochs 
n_epochs = 15


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# call training function
losses = train(D, G, n_epochs=n_epochs)
# Out:
# Epoch [    1/   15] | d_loss: 0.8722 | g_loss: 1.5200
# Epoch [    1/   15] | d_loss: 1.3406 | g_loss: 0.8574
# Epoch [    1/   15] | d_loss: 1.3264 | g_loss: 0.8518
# Epoch [    1/   15] | d_loss: 1.2644 | g_loss: 1.0663
# Epoch [    1/   15] | d_loss: 1.2439 | g_loss: 0.9665
# Epoch [    1/   15] | d_loss: 1.3673 | g_loss: 0.9180
# Epoch [    1/   15] | d_loss: 1.2860 | g_loss: 0.9672
# Epoch [    1/   15] | d_loss: 1.3034 | g_loss: 0.8347
# Epoch [    1/   15] | d_loss: 1.2477 | g_loss: 1.0528
# Epoch [    1/   15] | d_loss: 1.3493 | g_loss: 1.0901
# Epoch [    1/   15] | d_loss: 1.4302 | g_loss: 0.8729
# Epoch [    1/   15] | d_loss: 1.2200 | g_loss: 1.0354
# Epoch [    1/   15] | d_loss: 1.3540 | g_loss: 0.9432
# Epoch [    1/   15] | d_loss: 1.3235 | g_loss: 1.0072
# Epoch [    1/   15] | d_loss: 1.5094 | g_loss: 0.9064
# Epoch [    1/   15] | d_loss: 1.3410 | g_loss: 0.9316
# Epoch [    1/   15] | d_loss: 1.3866 | g_loss: 0.9436
# Epoch [    1/   15] | d_loss: 1.3567 | g_loss: 1.0326
# Epoch [    1/   15] | d_loss: 1.2458 | g_loss: 1.2032
# Epoch [    1/   15] | d_loss: 1.3619 | g_loss: 1.0022
# Epoch [    1/   15] | d_loss: 1.2869 | g_loss: 0.9486
# Epoch [    1/   15] | d_loss: 1.2170 | g_loss: 1.1882
# Epoch [    1/   15] | d_loss: 1.3956 | g_loss: 0.9304
# Epoch [    1/   15] | d_loss: 1.1910 | g_loss: 0.9791
# Epoch [    1/   15] | d_loss: 1.1688 | g_loss: 1.2269
# Epoch [    1/   15] | d_loss: 1.1724 | g_loss: 1.0717
# Epoch [    1/   15] | d_loss: 1.3588 | g_loss: 0.9153
# Epoch [    1/   15] | d_loss: 1.1838 | g_loss: 1.0285
# Epoch [    1/   15] | d_loss: 1.2385 | g_loss: 0.9969
# Epoch [    1/   15] | d_loss: 1.4654 | g_loss: 1.0338
# Epoch [    1/   15] | d_loss: 1.3067 | g_loss: 0.8706
# Epoch [    1/   15] | d_loss: 1.3187 | g_loss: 1.1053
# Epoch [    1/   15] | d_loss: 1.2656 | g_loss: 1.0749
# Epoch [    1/   15] | d_loss: 1.3952 | g_loss: 0.9119
# Epoch [    1/   15] | d_loss: 1.2043 | g_loss: 0.9802
# Epoch [    1/   15] | d_loss: 1.3172 | g_loss: 1.0801
# Epoch [    1/   15] | d_loss: 1.2841 | g_loss: 1.1936
# Epoch [    1/   15] | d_loss: 1.2382 | g_loss: 0.9983
# Epoch [    1/   15] | d_loss: 1.2411 | g_loss: 1.0260
# Epoch [    1/   15] | d_loss: 1.3725 | g_loss: 0.7399
# Epoch [    1/   15] | d_loss: 1.3563 | g_loss: 0.9454
# Epoch [    1/   15] | d_loss: 1.3833 | g_loss: 0.8633
# Epoch [    1/   15] | d_loss: 1.2090 | g_loss: 0.9731
# Epoch [    1/   15] | d_loss: 1.2630 | g_loss: 0.9600
# Epoch [    1/   15] | d_loss: 1.2205 | g_loss: 0.9022
# Epoch [    1/   15] | d_loss: 1.1771 | g_loss: 1.0738
# Epoch [    1/   15] | d_loss: 1.3364 | g_loss: 1.0927
# Epoch [    1/   15] | d_loss: 1.3779 | g_loss: 0.8593
# Epoch [    1/   15] | d_loss: 1.3413 | g_loss: 0.9934
# Epoch [    1/   15] | d_loss: 1.2688 | g_loss: 1.0564
# Epoch [    1/   15] | d_loss: 1.3520 | g_loss: 0.9900
# Epoch [    1/   15] | d_loss: 1.4069 | g_loss: 0.8832
# Epoch [    1/   15] | d_loss: 1.2068 | g_loss: 0.9606
# Epoch [    1/   15] | d_loss: 1.3501 | g_loss: 1.0839
# Epoch [    1/   15] | d_loss: 1.3697 | g_loss: 0.9630
# Epoch [    1/   15] | d_loss: 1.4580 | g_loss: 0.7890
# Epoch [    1/   15] | d_loss: 1.3110 | g_loss: 1.0607
# Epoch [    1/   15] | d_loss: 1.3202 | g_loss: 0.9151
# Epoch [    1/   15] | d_loss: 1.1453 | g_loss: 0.9941
# Epoch [    1/   15] | d_loss: 1.3789 | g_loss: 0.9439
# Epoch [    1/   15] | d_loss: 1.2653 | g_loss: 1.1339
# Epoch [    1/   15] | d_loss: 1.0650 | g_loss: 1.1480
# Epoch [    1/   15] | d_loss: 1.3196 | g_loss: 0.8711
# Epoch [    1/   15] | d_loss: 1.2452 | g_loss: 0.9537
# Epoch [    1/   15] | d_loss: 1.1421 | g_loss: 1.0852
# Epoch [    1/   15] | d_loss: 1.3407 | g_loss: 0.9746
# Epoch [    1/   15] | d_loss: 1.0123 | g_loss: 1.4421
# Epoch [    1/   15] | d_loss: 1.2012 | g_loss: 0.9034
# Epoch [    1/   15] | d_loss: 1.2193 | g_loss: 0.9937
# Epoch [    1/   15] | d_loss: 1.2576 | g_loss: 0.9101
# Epoch [    1/   15] | d_loss: 1.3102 | g_loss: 0.8489
# Epoch [    1/   15] | d_loss: 1.2237 | g_loss: 1.0442
# Epoch [    1/   15] | d_loss: 1.4823 | g_loss: 0.8907
# Epoch [    1/   15] | d_loss: 1.1106 | g_loss: 1.1575
# Epoch [    1/   15] | d_loss: 1.1692 | g_loss: 1.1248
# Epoch [    1/   15] | d_loss: 1.2683 | g_loss: 1.1318
# Epoch [    1/   15] | d_loss: 1.3846 | g_loss: 0.7052
# Epoch [    1/   15] | d_loss: 1.2691 | g_loss: 0.7998
# Epoch [    1/   15] | d_loss: 1.1143 | g_loss: 1.1413
# Epoch [    1/   15] | d_loss: 1.1559 | g_loss: 1.3272
# Epoch [    1/   15] | d_loss: 0.9498 | g_loss: 1.7289
# Epoch [    1/   15] | d_loss: 1.1779 | g_loss: 1.2231
# Epoch [    1/   15] | d_loss: 1.2895 | g_loss: 1.0417
# Epoch [    1/   15] | d_loss: 1.2944 | g_loss: 1.1943
# Epoch [    1/   15] | d_loss: 1.2989 | g_loss: 1.0653
# Epoch [    1/   15] | d_loss: 1.1879 | g_loss: 0.9655
# Epoch [    1/   15] | d_loss: 1.3292 | g_loss: 1.0298
# Epoch [    1/   15] | d_loss: 1.4118 | g_loss: 1.0768
# Epoch [    1/   15] | d_loss: 1.2538 | g_loss: 1.1381
# Epoch [    1/   15] | d_loss: 1.1790 | g_loss: 0.9855
# Epoch [    1/   15] | d_loss: 1.4111 | g_loss: 0.8855
# Epoch [    1/   15] | d_loss: 1.1122 | g_loss: 1.3059
# Epoch [    1/   15] | d_loss: 1.1985 | g_loss: 1.1264
# Epoch [    1/   15] | d_loss: 1.2745 | g_loss: 1.0494
# Epoch [    1/   15] | d_loss: 1.2927 | g_loss: 1.0071
# Epoch [    1/   15] | d_loss: 1.4158 | g_loss: 0.8799
# Epoch [    1/   15] | d_loss: 1.1036 | g_loss: 1.3507
# Epoch [    1/   15] | d_loss: 1.3162 | g_loss: 1.0251
# Epoch [    1/   15] | d_loss: 1.0863 | g_loss: 1.4298
# Epoch [    1/   15] | d_loss: 0.9948 | g_loss: 1.2827
# Epoch [    1/   15] | d_loss: 1.2114 | g_loss: 1.0365
# Epoch [    1/   15] | d_loss: 1.1332 | g_loss: 1.3317
# Epoch [    1/   15] | d_loss: 1.1801 | g_loss: 0.9078
# Epoch [    1/   15] | d_loss: 1.3362 | g_loss: 0.9827
# Epoch [    1/   15] | d_loss: 1.2560 | g_loss: 1.0260
# Epoch [    1/   15] | d_loss: 1.1297 | g_loss: 1.1343
# Epoch [    1/   15] | d_loss: 1.2458 | g_loss: 1.0171
# Epoch [    1/   15] | d_loss: 1.1776 | g_loss: 1.2465
# Epoch [    1/   15] | d_loss: 1.1441 | g_loss: 1.2139
# Epoch [    1/   15] | d_loss: 1.3211 | g_loss: 0.8817
# Epoch [    1/   15] | d_loss: 1.2475 | g_loss: 1.2809
# Epoch [    1/   15] | d_loss: 1.2299 | g_loss: 1.1685
# Epoch [    1/   15] | d_loss: 1.1723 | g_loss: 1.0991
# Epoch [    2/   15] | d_loss: 1.4040 | g_loss: 0.8982
# Epoch [    2/   15] | d_loss: 1.2540 | g_loss: 0.8870
# Epoch [    2/   15] | d_loss: 1.1276 | g_loss: 1.1755
# Epoch [    2/   15] | d_loss: 1.2119 | g_loss: 1.0368
# Epoch [    2/   15] | d_loss: 1.0458 | g_loss: 1.8262
# Epoch [    2/   15] | d_loss: 1.1667 | g_loss: 1.1688
# Epoch [    2/   15] | d_loss: 0.9826 | g_loss: 1.4466
# Epoch [    2/   15] | d_loss: 1.1193 | g_loss: 1.0046
# Epoch [    2/   15] | d_loss: 1.0100 | g_loss: 1.3223
# Epoch [    2/   15] | d_loss: 1.0592 | g_loss: 1.2496
# Epoch [    2/   15] | d_loss: 1.2233 | g_loss: 1.0913
# Epoch [    2/   15] | d_loss: 1.1613 | g_loss: 1.3442
# Epoch [    2/   15] | d_loss: 1.0917 | g_loss: 1.0151
# Epoch [    2/   15] | d_loss: 1.1100 | g_loss: 1.1353
# Epoch [    2/   15] | d_loss: 1.4769 | g_loss: 1.1379
# Epoch [    2/   15] | d_loss: 1.0882 | g_loss: 1.4406
# Epoch [    2/   15] | d_loss: 1.4079 | g_loss: 1.0520
# Epoch [    2/   15] | d_loss: 1.2262 | g_loss: 1.0520
# Epoch [    2/   15] | d_loss: 1.2684 | g_loss: 1.1076
# Epoch [    2/   15] | d_loss: 1.2428 | g_loss: 1.3613
# Epoch [    2/   15] | d_loss: 0.9528 | g_loss: 1.5130
# Epoch [    2/   15] | d_loss: 1.1062 | g_loss: 1.2954
# Epoch [    2/   15] | d_loss: 1.2514 | g_loss: 1.3110
# Epoch [    2/   15] | d_loss: 1.0970 | g_loss: 1.4066
# Epoch [    2/   15] | d_loss: 1.4157 | g_loss: 0.8667
# Epoch [    2/   15] | d_loss: 1.4697 | g_loss: 0.9698
# Epoch [    2/   15] | d_loss: 1.4708 | g_loss: 0.8759
# Epoch [    2/   15] | d_loss: 1.5188 | g_loss: 0.8944
# Epoch [    2/   15] | d_loss: 1.4714 | g_loss: 0.9552
# Epoch [    2/   15] | d_loss: 1.2790 | g_loss: 1.2730
# Epoch [    2/   15] | d_loss: 1.0316 | g_loss: 1.0617
# Epoch [    2/   15] | d_loss: 1.2249 | g_loss: 1.1560
# Epoch [    2/   15] | d_loss: 1.2399 | g_loss: 1.1557
# Epoch [    2/   15] | d_loss: 1.1044 | g_loss: 1.2012
# Epoch [    2/   15] | d_loss: 0.9267 | g_loss: 1.2315
# Epoch [    2/   15] | d_loss: 1.4385 | g_loss: 0.8117
# Epoch [    2/   15] | d_loss: 1.2950 | g_loss: 1.0358
# Epoch [    2/   15] | d_loss: 1.4137 | g_loss: 0.8432
# Epoch [    2/   15] | d_loss: 1.1732 | g_loss: 0.8474
# Epoch [    2/   15] | d_loss: 1.1136 | g_loss: 1.2343
# Epoch [    2/   15] | d_loss: 1.2665 | g_loss: 1.2861
# Epoch [    2/   15] | d_loss: 1.2361 | g_loss: 1.2507
# Epoch [    2/   15] | d_loss: 1.3183 | g_loss: 0.7909
# Epoch [    2/   15] | d_loss: 1.0346 | g_loss: 2.0443
# Epoch [    2/   15] | d_loss: 1.2462 | g_loss: 0.9773
# Epoch [    2/   15] | d_loss: 1.2382 | g_loss: 0.8610
# Epoch [    2/   15] | d_loss: 1.1639 | g_loss: 1.2289
# Epoch [    2/   15] | d_loss: 1.4501 | g_loss: 1.2092
# Epoch [    2/   15] | d_loss: 1.4079 | g_loss: 1.0574
# Epoch [    2/   15] | d_loss: 1.0811 | g_loss: 1.2515
# Epoch [    2/   15] | d_loss: 1.0014 | g_loss: 1.2429
# Epoch [    2/   15] | d_loss: 1.0277 | g_loss: 1.4588
# Epoch [    2/   15] | d_loss: 1.2310 | g_loss: 0.9515
# Epoch [    2/   15] | d_loss: 1.1522 | g_loss: 1.1402
# Epoch [    2/   15] | d_loss: 1.3442 | g_loss: 1.2803
# Epoch [    2/   15] | d_loss: 1.3446 | g_loss: 0.7937
# Epoch [    2/   15] | d_loss: 1.2097 | g_loss: 1.5069
# Epoch [    2/   15] | d_loss: 0.9423 | g_loss: 1.7799
# Epoch [    2/   15] | d_loss: 0.8901 | g_loss: 1.5288
# Epoch [    2/   15] | d_loss: 1.4264 | g_loss: 0.7724
# Epoch [    2/   15] | d_loss: 1.0178 | g_loss: 1.3671
# Epoch [    2/   15] | d_loss: 0.8947 | g_loss: 1.6483
# Epoch [    2/   15] | d_loss: 1.2039 | g_loss: 1.1364
# Epoch [    2/   15] | d_loss: 1.0435 | g_loss: 1.1148
# Epoch [    2/   15] | d_loss: 1.0826 | g_loss: 1.1308
# Epoch [    2/   15] | d_loss: 0.9718 | g_loss: 1.4327
# Epoch [    2/   15] | d_loss: 1.2441 | g_loss: 1.2394
# Epoch [    2/   15] | d_loss: 1.5441 | g_loss: 0.8748
# Epoch [    2/   15] | d_loss: 1.1365 | g_loss: 1.2962
# Epoch [    2/   15] | d_loss: 1.0316 | g_loss: 1.4398
# Epoch [    2/   15] | d_loss: 1.0407 | g_loss: 1.5271
# Epoch [    2/   15] | d_loss: 1.1353 | g_loss: 1.2234
# Epoch [    2/   15] | d_loss: 1.0477 | g_loss: 1.2799
# Epoch [    2/   15] | d_loss: 1.3286 | g_loss: 0.7648
# Epoch [    2/   15] | d_loss: 1.1730 | g_loss: 1.0081
# Epoch [    2/   15] | d_loss: 1.2554 | g_loss: 0.8149
# Epoch [    2/   15] | d_loss: 0.9236 | g_loss: 1.1123
# Epoch [    2/   15] | d_loss: 1.0743 | g_loss: 1.2113
# Epoch [    2/   15] | d_loss: 0.8754 | g_loss: 1.8796
# Epoch [    2/   15] | d_loss: 1.5331 | g_loss: 0.7985
# Epoch [    2/   15] | d_loss: 1.1158 | g_loss: 1.2297
# Epoch [    2/   15] | d_loss: 1.0236 | g_loss: 1.3048
# Epoch [    2/   15] | d_loss: 1.3451 | g_loss: 1.1108
# Epoch [    2/   15] | d_loss: 1.2298 | g_loss: 1.0784
# Epoch [    2/   15] | d_loss: 1.1831 | g_loss: 1.3051
# Epoch [    2/   15] | d_loss: 1.1308 | g_loss: 1.4957
# Epoch [    2/   15] | d_loss: 1.2259 | g_loss: 1.0953
# Epoch [    2/   15] | d_loss: 0.8706 | g_loss: 1.6239
# Epoch [    2/   15] | d_loss: 1.2110 | g_loss: 1.3205
# Epoch [    2/   15] | d_loss: 1.2356 | g_loss: 1.4638
# Epoch [    2/   15] | d_loss: 0.8699 | g_loss: 1.7388
# Epoch [    2/   15] | d_loss: 0.7633 | g_loss: 1.7555
# Epoch [    2/   15] | d_loss: 0.7631 | g_loss: 1.8504
# Epoch [    2/   15] | d_loss: 1.1953 | g_loss: 1.2493
# Epoch [    2/   15] | d_loss: 1.1476 | g_loss: 1.7942
# Epoch [    2/   15] | d_loss: 1.0766 | g_loss: 1.3840
# Epoch [    2/   15] | d_loss: 0.7421 | g_loss: 1.5067
# Epoch [    2/   15] | d_loss: 1.2116 | g_loss: 1.1675
# Epoch [    2/   15] | d_loss: 1.2273 | g_loss: 1.3095
# Epoch [    2/   15] | d_loss: 1.0120 | g_loss: 1.4228
# Epoch [    2/   15] | d_loss: 1.6596 | g_loss: 1.0266
# Epoch [    2/   15] | d_loss: 1.0794 | g_loss: 1.2133
# Epoch [    2/   15] | d_loss: 1.1875 | g_loss: 1.2406
# Epoch [    2/   15] | d_loss: 0.9182 | g_loss: 1.7245
# Epoch [    2/   15] | d_loss: 1.0240 | g_loss: 1.3727
# Epoch [    2/   15] | d_loss: 1.0747 | g_loss: 1.7796
# Epoch [    2/   15] | d_loss: 1.2009 | g_loss: 0.9598
# Epoch [    2/   15] | d_loss: 1.3895 | g_loss: 1.1048
# Epoch [    2/   15] | d_loss: 1.0293 | g_loss: 1.5217
# Epoch [    2/   15] | d_loss: 1.1181 | g_loss: 1.2422
# Epoch [    2/   15] | d_loss: 1.0321 | g_loss: 1.5250
# Epoch [    2/   15] | d_loss: 0.7364 | g_loss: 2.0101
# Epoch [    2/   15] | d_loss: 1.1691 | g_loss: 1.4401
# Epoch [    3/   15] | d_loss: 0.9668 | g_loss: 1.1650
# Epoch [    3/   15] | d_loss: 1.2212 | g_loss: 1.1784
# Epoch [    3/   15] | d_loss: 0.9226 | g_loss: 1.7673
# Epoch [    3/   15] | d_loss: 1.0518 | g_loss: 1.2854
# Epoch [    3/   15] | d_loss: 1.1913 | g_loss: 0.9477
# Epoch [    3/   15] | d_loss: 1.0503 | g_loss: 1.2377
# Epoch [    3/   15] | d_loss: 1.0584 | g_loss: 1.2973
# Epoch [    3/   15] | d_loss: 1.1603 | g_loss: 1.3929
# Epoch [    3/   15] | d_loss: 1.3507 | g_loss: 1.0770
# Epoch [    3/   15] | d_loss: 1.2529 | g_loss: 0.9260
# Epoch [    3/   15] | d_loss: 0.9818 | g_loss: 1.4549
# Epoch [    3/   15] | d_loss: 1.0503 | g_loss: 1.5631
# Epoch [    3/   15] | d_loss: 1.3247 | g_loss: 1.1617
# Epoch [    3/   15] | d_loss: 0.8398 | g_loss: 1.4707
# Epoch [    3/   15] | d_loss: 1.5004 | g_loss: 1.2765
# Epoch [    3/   15] | d_loss: 1.2189 | g_loss: 1.0622
# Epoch [    3/   15] | d_loss: 1.0580 | g_loss: 1.1894
# Epoch [    3/   15] | d_loss: 0.8888 | g_loss: 1.9976
# Epoch [    3/   15] | d_loss: 0.9311 | g_loss: 1.9154
# Epoch [    3/   15] | d_loss: 1.2807 | g_loss: 1.3711
# Epoch [    3/   15] | d_loss: 0.7151 | g_loss: 2.0378
# Epoch [    3/   15] | d_loss: 1.2548 | g_loss: 1.1402
# Epoch [    3/   15] | d_loss: 0.8404 | g_loss: 1.5505
# Epoch [    3/   15] | d_loss: 0.9433 | g_loss: 1.3962
# Epoch [    3/   15] | d_loss: 1.2993 | g_loss: 0.9370
# Epoch [    3/   15] | d_loss: 1.1040 | g_loss: 1.2729
# Epoch [    3/   15] | d_loss: 1.0580 | g_loss: 1.2302
# Epoch [    3/   15] | d_loss: 1.2724 | g_loss: 0.9561
# Epoch [    3/   15] | d_loss: 1.3480 | g_loss: 1.0489
# Epoch [    3/   15] | d_loss: 1.0136 | g_loss: 1.2426
# Epoch [    3/   15] | d_loss: 1.3713 | g_loss: 1.0276
# Epoch [    3/   15] | d_loss: 1.5681 | g_loss: 0.7378
# Epoch [    3/   15] | d_loss: 1.2629 | g_loss: 1.4117
# Epoch [    3/   15] | d_loss: 1.0670 | g_loss: 1.7214
# Epoch [    3/   15] | d_loss: 1.0547 | g_loss: 1.2247
# Epoch [    3/   15] | d_loss: 1.6127 | g_loss: 1.3159
# Epoch [    3/   15] | d_loss: 1.3015 | g_loss: 1.1261
# Epoch [    3/   15] | d_loss: 0.9210 | g_loss: 1.7343
# Epoch [    3/   15] | d_loss: 1.2027 | g_loss: 0.9727
# Epoch [    3/   15] | d_loss: 1.0294 | g_loss: 1.4305
# Epoch [    3/   15] | d_loss: 1.2931 | g_loss: 1.2510
# Epoch [    3/   15] | d_loss: 0.8173 | g_loss: 1.5692
# Epoch [    3/   15] | d_loss: 0.9465 | g_loss: 1.6958
# Epoch [    3/   15] | d_loss: 1.0201 | g_loss: 1.2430
# Epoch [    3/   15] | d_loss: 1.1888 | g_loss: 1.2010
# Epoch [    3/   15] | d_loss: 0.9871 | g_loss: 2.3493
# Epoch [    3/   15] | d_loss: 1.0573 | g_loss: 1.2892
# Epoch [    3/   15] | d_loss: 0.9830 | g_loss: 1.8586
# Epoch [    3/   15] | d_loss: 0.9949 | g_loss: 1.8157
# Epoch [    3/   15] | d_loss: 0.9084 | g_loss: 1.5012
# Epoch [    3/   15] | d_loss: 1.0280 | g_loss: 1.2504
# Epoch [    3/   15] | d_loss: 1.0368 | g_loss: 1.4046
# Epoch [    3/   15] | d_loss: 1.0802 | g_loss: 1.4834
# Epoch [    3/   15] | d_loss: 1.1597 | g_loss: 1.8810
# Epoch [    3/   15] | d_loss: 0.9960 | g_loss: 1.1572
# Epoch [    3/   15] | d_loss: 1.3334 | g_loss: 1.2674
# Epoch [    3/   15] | d_loss: 1.0418 | g_loss: 1.5073
# Epoch [    3/   15] | d_loss: 1.5140 | g_loss: 0.9279
# Epoch [    3/   15] | d_loss: 1.4046 | g_loss: 1.0939
# Epoch [    3/   15] | d_loss: 0.7175 | g_loss: 1.8754
# Epoch [    3/   15] | d_loss: 1.5468 | g_loss: 1.1947
# Epoch [    3/   15] | d_loss: 0.9653 | g_loss: 1.6294
# Epoch [    3/   15] | d_loss: 1.0312 | g_loss: 1.5372
# Epoch [    3/   15] | d_loss: 0.6408 | g_loss: 2.2474
# Epoch [    3/   15] | d_loss: 1.1708 | g_loss: 1.1087
# Epoch [    3/   15] | d_loss: 1.5227 | g_loss: 1.1114
# Epoch [    3/   15] | d_loss: 0.9010 | g_loss: 1.7888
# Epoch [    3/   15] | d_loss: 0.8480 | g_loss: 1.3766
# Epoch [    3/   15] | d_loss: 1.3284 | g_loss: 1.0543
# Epoch [    3/   15] | d_loss: 1.0883 | g_loss: 1.0923
# Epoch [    3/   15] | d_loss: 0.7993 | g_loss: 1.6529
# Epoch [    3/   15] | d_loss: 1.0555 | g_loss: 1.5934
# Epoch [    3/   15] | d_loss: 0.7922 | g_loss: 1.5204
# Epoch [    3/   15] | d_loss: 0.9089 | g_loss: 1.7204
# Epoch [    3/   15] | d_loss: 1.0053 | g_loss: 1.5262
# Epoch [    3/   15] | d_loss: 0.9558 | g_loss: 1.4891
# Epoch [    3/   15] | d_loss: 0.7007 | g_loss: 2.0538
# Epoch [    3/   15] | d_loss: 0.9779 | g_loss: 1.2631
# Epoch [    3/   15] | d_loss: 1.4406 | g_loss: 0.8632
# Epoch [    3/   15] | d_loss: 1.0784 | g_loss: 1.9833
# Epoch [    3/   15] | d_loss: 0.9307 | g_loss: 1.3077
# Epoch [    3/   15] | d_loss: 1.0891 | g_loss: 1.4638
# Epoch [    3/   15] | d_loss: 1.1733 | g_loss: 1.0802
# Epoch [    3/   15] | d_loss: 0.9082 | g_loss: 1.3844
# Epoch [    3/   15] | d_loss: 0.9330 | g_loss: 1.6742
# Epoch [    3/   15] | d_loss: 0.8024 | g_loss: 1.6217
# Epoch [    3/   15] | d_loss: 0.9678 | g_loss: 1.8999
# Epoch [    3/   15] | d_loss: 0.8899 | g_loss: 1.6083
# Epoch [    3/   15] | d_loss: 1.3631 | g_loss: 0.6756
# Epoch [    3/   15] | d_loss: 2.1831 | g_loss: 0.6491
# Epoch [    3/   15] | d_loss: 0.9313 | g_loss: 1.6579
# Epoch [    3/   15] | d_loss: 1.0919 | g_loss: 1.2427
# Epoch [    3/   15] | d_loss: 0.7215 | g_loss: 1.5210
# Epoch [    3/   15] | d_loss: 1.0779 | g_loss: 1.2912
# Epoch [    3/   15] | d_loss: 0.9708 | g_loss: 1.6223
# Epoch [    3/   15] | d_loss: 1.6540 | g_loss: 0.9302
# Epoch [    3/   15] | d_loss: 1.0608 | g_loss: 1.3818
# Epoch [    3/   15] | d_loss: 1.1389 | g_loss: 0.9990
# Epoch [    3/   15] | d_loss: 1.0381 | g_loss: 2.0861
# Epoch [    3/   15] | d_loss: 0.8822 | g_loss: 1.6272
# Epoch [    3/   15] | d_loss: 1.0198 | g_loss: 1.4089
# Epoch [    3/   15] | d_loss: 0.8614 | g_loss: 1.7310
# Epoch [    3/   15] | d_loss: 1.0845 | g_loss: 1.5653
# Epoch [    3/   15] | d_loss: 0.9649 | g_loss: 1.6609
# Epoch [    3/   15] | d_loss: 0.9068 | g_loss: 1.4247
# Epoch [    3/   15] | d_loss: 0.7603 | g_loss: 1.8903
# Epoch [    3/   15] | d_loss: 1.0212 | g_loss: 1.4069
# Epoch [    3/   15] | d_loss: 0.8377 | g_loss: 1.4719
# Epoch [    3/   15] | d_loss: 0.8747 | g_loss: 1.6741
# Epoch [    3/   15] | d_loss: 1.0159 | g_loss: 1.3447
# Epoch [    3/   15] | d_loss: 1.1878 | g_loss: 1.0207
# Epoch [    3/   15] | d_loss: 0.9989 | g_loss: 1.4642
# Epoch [    3/   15] | d_loss: 1.8000 | g_loss: 1.2763
# Epoch [    4/   15] | d_loss: 0.7463 | g_loss: 1.9146
# Epoch [    4/   15] | d_loss: 0.9121 | g_loss: 1.4425
# Epoch [    4/   15] | d_loss: 0.9069 | g_loss: 2.1961
# Epoch [    4/   15] | d_loss: 0.8644 | g_loss: 1.5632
# Epoch [    4/   15] | d_loss: 0.8792 | g_loss: 1.6679
# Epoch [    4/   15] | d_loss: 0.8518 | g_loss: 1.5368
# Epoch [    4/   15] | d_loss: 0.7685 | g_loss: 1.8483
# Epoch [    4/   15] | d_loss: 0.8711 | g_loss: 2.1791
# Epoch [    4/   15] | d_loss: 0.9340 | g_loss: 1.3334
# Epoch [    4/   15] | d_loss: 1.1847 | g_loss: 1.5851
# Epoch [    4/   15] | d_loss: 0.8924 | g_loss: 1.9279
# Epoch [    4/   15] | d_loss: 0.6447 | g_loss: 1.8970
# Epoch [    4/   15] | d_loss: 1.0998 | g_loss: 2.2768
# Epoch [    4/   15] | d_loss: 1.1873 | g_loss: 1.3231
# Epoch [    4/   15] | d_loss: 0.9371 | g_loss: 1.7144
# Epoch [    4/   15] | d_loss: 0.8626 | g_loss: 1.5724
# Epoch [    4/   15] | d_loss: 1.2528 | g_loss: 1.0824
# Epoch [    4/   15] | d_loss: 0.6241 | g_loss: 2.0534
# Epoch [    4/   15] | d_loss: 0.5552 | g_loss: 2.6470
# Epoch [    4/   15] | d_loss: 0.8135 | g_loss: 1.6895
# Epoch [    4/   15] | d_loss: 1.0377 | g_loss: 1.2761
# Epoch [    4/   15] | d_loss: 0.8921 | g_loss: 1.6240
# Epoch [    4/   15] | d_loss: 1.1422 | g_loss: 1.3051
# Epoch [    4/   15] | d_loss: 1.1976 | g_loss: 1.8025
# Epoch [    4/   15] | d_loss: 1.1154 | g_loss: 1.9649
# Epoch [    4/   15] | d_loss: 0.7619 | g_loss: 1.6118
# Epoch [    4/   15] | d_loss: 1.0324 | g_loss: 1.8081
# Epoch [    4/   15] | d_loss: 0.7716 | g_loss: 2.1809
# Epoch [    4/   15] | d_loss: 0.7308 | g_loss: 2.5777
# Epoch [    4/   15] | d_loss: 0.9147 | g_loss: 2.1344
# Epoch [    4/   15] | d_loss: 0.7878 | g_loss: 1.5845
# Epoch [    4/   15] | d_loss: 0.9655 | g_loss: 1.4589
# Epoch [    4/   15] | d_loss: 1.0059 | g_loss: 2.3464
# Epoch [    4/   15] | d_loss: 0.9701 | g_loss: 1.6783
# Epoch [    4/   15] | d_loss: 1.7797 | g_loss: 0.9454
# Epoch [    4/   15] | d_loss: 0.9127 | g_loss: 1.3053
# Epoch [    4/   15] | d_loss: 0.9747 | g_loss: 1.5440
# Epoch [    4/   15] | d_loss: 0.9222 | g_loss: 2.2635
# Epoch [    4/   15] | d_loss: 0.8541 | g_loss: 1.8153
# Epoch [    4/   15] | d_loss: 1.0537 | g_loss: 1.5943
# Epoch [    4/   15] | d_loss: 0.9599 | g_loss: 1.5227
# Epoch [    4/   15] | d_loss: 0.7641 | g_loss: 1.9570
# Epoch [    4/   15] | d_loss: 0.9221 | g_loss: 2.0929
# Epoch [    4/   15] | d_loss: 0.8722 | g_loss: 2.1621
# Epoch [    4/   15] | d_loss: 1.0659 | g_loss: 1.5023
# Epoch [    4/   15] | d_loss: 1.0965 | g_loss: 1.4206
# Epoch [    4/   15] | d_loss: 0.6069 | g_loss: 2.2946
# Epoch [    4/   15] | d_loss: 1.2086 | g_loss: 1.4325
# Epoch [    4/   15] | d_loss: 1.0161 | g_loss: 1.5975
# Epoch [    4/   15] | d_loss: 0.7853 | g_loss: 1.6844
# Epoch [    4/   15] | d_loss: 1.2987 | g_loss: 1.1322
# Epoch [    4/   15] | d_loss: 0.7163 | g_loss: 2.1119
# Epoch [    4/   15] | d_loss: 0.7957 | g_loss: 1.9225
# Epoch [    4/   15] | d_loss: 1.3532 | g_loss: 1.2394
# Epoch [    4/   15] | d_loss: 0.8769 | g_loss: 1.6599
# Epoch [    4/   15] | d_loss: 1.3777 | g_loss: 1.1063
# Epoch [    4/   15] | d_loss: 0.7702 | g_loss: 1.7229
# Epoch [    4/   15] | d_loss: 1.0894 | g_loss: 1.1246
# Epoch [    4/   15] | d_loss: 1.0190 | g_loss: 1.7774
# Epoch [    4/   15] | d_loss: 1.1313 | g_loss: 1.2240
# Epoch [    4/   15] | d_loss: 0.8975 | g_loss: 2.0911
# Epoch [    4/   15] | d_loss: 1.1108 | g_loss: 1.7816
# Epoch [    4/   15] | d_loss: 1.1745 | g_loss: 1.1397
# Epoch [    4/   15] | d_loss: 0.8248 | g_loss: 1.4195
# Epoch [    4/   15] | d_loss: 1.0389 | g_loss: 2.5100
# Epoch [    4/   15] | d_loss: 1.6994 | g_loss: 0.8434
# Epoch [    4/   15] | d_loss: 0.7971 | g_loss: 2.2650
# Epoch [    4/   15] | d_loss: 1.1092 | g_loss: 1.9106
# Epoch [    4/   15] | d_loss: 0.9122 | g_loss: 1.2903
# Epoch [    4/   15] | d_loss: 0.8900 | g_loss: 1.6983
# Epoch [    4/   15] | d_loss: 0.8961 | g_loss: 2.2237
# Epoch [    4/   15] | d_loss: 1.2885 | g_loss: 1.6307
# Epoch [    4/   15] | d_loss: 1.4046 | g_loss: 2.1881
# Epoch [    4/   15] | d_loss: 0.8593 | g_loss: 2.8412
# Epoch [    4/   15] | d_loss: 0.6313 | g_loss: 1.7072
# Epoch [    4/   15] | d_loss: 0.9210 | g_loss: 1.6278
# Epoch [    4/   15] | d_loss: 1.3859 | g_loss: 1.4297
# Epoch [    4/   15] | d_loss: 0.9297 | g_loss: 1.3491
# Epoch [    4/   15] | d_loss: 0.8540 | g_loss: 1.7694
# Epoch [    4/   15] | d_loss: 0.8145 | g_loss: 1.8932
# Epoch [    4/   15] | d_loss: 1.2937 | g_loss: 1.7044
# Epoch [    4/   15] | d_loss: 0.9493 | g_loss: 1.7651
# Epoch [    4/   15] | d_loss: 1.0931 | g_loss: 1.1440
# Epoch [    4/   15] | d_loss: 1.2964 | g_loss: 0.9015
# Epoch [    4/   15] | d_loss: 0.9984 | g_loss: 1.6853
# Epoch [    4/   15] | d_loss: 0.7708 | g_loss: 2.4290
# Epoch [    4/   15] | d_loss: 1.3592 | g_loss: 2.0234
# Epoch [    4/   15] | d_loss: 0.8737 | g_loss: 2.4927
# Epoch [    4/   15] | d_loss: 0.7620 | g_loss: 1.7918
# Epoch [    4/   15] | d_loss: 0.8407 | g_loss: 2.2629
# Epoch [    4/   15] | d_loss: 1.0516 | g_loss: 1.7121
# Epoch [    4/   15] | d_loss: 1.2572 | g_loss: 1.8420
# Epoch [    4/   15] | d_loss: 1.2198 | g_loss: 1.2493
# Epoch [    4/   15] | d_loss: 0.7061 | g_loss: 2.5191
# Epoch [    4/   15] | d_loss: 0.6322 | g_loss: 2.3115
# Epoch [    4/   15] | d_loss: 0.6498 | g_loss: 2.1669
# Epoch [    4/   15] | d_loss: 1.0421 | g_loss: 1.3419
# Epoch [    4/   15] | d_loss: 0.8410 | g_loss: 2.2369
# Epoch [    4/   15] | d_loss: 1.3963 | g_loss: 0.9638
# Epoch [    4/   15] | d_loss: 0.9593 | g_loss: 1.5002
# Epoch [    4/   15] | d_loss: 0.9838 | g_loss: 1.3426
# Epoch [    4/   15] | d_loss: 0.8542 | g_loss: 2.0249
# Epoch [    4/   15] | d_loss: 0.5555 | g_loss: 2.8299
# Epoch [    4/   15] | d_loss: 0.7087 | g_loss: 1.9305
# Epoch [    4/   15] | d_loss: 1.0830 | g_loss: 2.8283
# Epoch [    4/   15] | d_loss: 0.9870 | g_loss: 1.7484
# Epoch [    4/   15] | d_loss: 0.6713 | g_loss: 2.3867
# Epoch [    4/   15] | d_loss: 1.1246 | g_loss: 1.1468
# Epoch [    4/   15] | d_loss: 0.9733 | g_loss: 1.3061
# Epoch [    4/   15] | d_loss: 1.5635 | g_loss: 0.7798
# Epoch [    4/   15] | d_loss: 0.7204 | g_loss: 2.0926
# Epoch [    4/   15] | d_loss: 0.6316 | g_loss: 2.6137
# Epoch [    4/   15] | d_loss: 1.2173 | g_loss: 1.0235
# Epoch [    5/   15] | d_loss: 0.7726 | g_loss: 1.6673
# Epoch [    5/   15] | d_loss: 1.2443 | g_loss: 1.1066
# Epoch [    5/   15] | d_loss: 0.8306 | g_loss: 1.8138
# Epoch [    5/   15] | d_loss: 0.8245 | g_loss: 1.8533
# Epoch [    5/   15] | d_loss: 0.7737 | g_loss: 1.6494
# Epoch [    5/   15] | d_loss: 0.8555 | g_loss: 1.4784
# Epoch [    5/   15] | d_loss: 1.1610 | g_loss: 1.5209
# Epoch [    5/   15] | d_loss: 1.0718 | g_loss: 1.6720
# Epoch [    5/   15] | d_loss: 0.8828 | g_loss: 2.1796
# Epoch [    5/   15] | d_loss: 1.2751 | g_loss: 1.4839
# Epoch [    5/   15] | d_loss: 0.9286 | g_loss: 1.6206
# Epoch [    5/   15] | d_loss: 0.7328 | g_loss: 2.6530
# Epoch [    5/   15] | d_loss: 0.6068 | g_loss: 2.4042
# Epoch [    5/   15] | d_loss: 1.3973 | g_loss: 1.6382
# Epoch [    5/   15] | d_loss: 0.7318 | g_loss: 2.0536
# Epoch [    5/   15] | d_loss: 0.7906 | g_loss: 1.5818
# Epoch [    5/   15] | d_loss: 0.9456 | g_loss: 2.3155
# Epoch [    5/   15] | d_loss: 0.7937 | g_loss: 2.5204
# Epoch [    5/   15] | d_loss: 1.0214 | g_loss: 1.9132
# Epoch [    5/   15] | d_loss: 0.6192 | g_loss: 2.0713
# Epoch [    5/   15] | d_loss: 1.0306 | g_loss: 2.3707
# Epoch [    5/   15] | d_loss: 0.6721 | g_loss: 2.1609
# Epoch [    5/   15] | d_loss: 0.9102 | g_loss: 1.7565
# Epoch [    5/   15] | d_loss: 0.7584 | g_loss: 2.1078
# Epoch [    5/   15] | d_loss: 0.8953 | g_loss: 1.8207
# Epoch [    5/   15] | d_loss: 0.8038 | g_loss: 2.2111
# Epoch [    5/   15] | d_loss: 0.5700 | g_loss: 2.5429
# Epoch [    5/   15] | d_loss: 1.2181 | g_loss: 1.0961
# Epoch [    5/   15] | d_loss: 0.9839 | g_loss: 1.8343
# Epoch [    5/   15] | d_loss: 0.8520 | g_loss: 1.5475
# Epoch [    5/   15] | d_loss: 0.8157 | g_loss: 1.6379
# Epoch [    5/   15] | d_loss: 1.1567 | g_loss: 1.5446
# Epoch [    5/   15] | d_loss: 1.2160 | g_loss: 1.1668
# Epoch [    5/   15] | d_loss: 1.0726 | g_loss: 1.5622
# Epoch [    5/   15] | d_loss: 0.7376 | g_loss: 2.2311
# Epoch [    5/   15] | d_loss: 1.4577 | g_loss: 1.0194
# Epoch [    5/   15] | d_loss: 1.5873 | g_loss: 0.8153
# Epoch [    5/   15] | d_loss: 1.0401 | g_loss: 1.2280
# Epoch [    5/   15] | d_loss: 0.9418 | g_loss: 1.5197
# Epoch [    5/   15] | d_loss: 1.3870 | g_loss: 1.1564
# Epoch [    5/   15] | d_loss: 0.9458 | g_loss: 1.4368
# Epoch [    5/   15] | d_loss: 0.9408 | g_loss: 2.0184
# Epoch [    5/   15] | d_loss: 0.9260 | g_loss: 2.6763
# Epoch [    5/   15] | d_loss: 1.1451 | g_loss: 1.4173
# Epoch [    5/   15] | d_loss: 0.9317 | g_loss: 2.0286
# Epoch [    5/   15] | d_loss: 1.1846 | g_loss: 1.2766
# Epoch [    5/   15] | d_loss: 0.5610 | g_loss: 2.1767
# Epoch [    5/   15] | d_loss: 0.9477 | g_loss: 1.8081
# Epoch [    5/   15] | d_loss: 1.1659 | g_loss: 1.1961
# Epoch [    5/   15] | d_loss: 0.8706 | g_loss: 1.9147
# Epoch [    5/   15] | d_loss: 2.0951 | g_loss: 0.8967
# Epoch [    5/   15] | d_loss: 0.8957 | g_loss: 1.8632
# Epoch [    5/   15] | d_loss: 0.8627 | g_loss: 3.0163
# Epoch [    5/   15] | d_loss: 0.7698 | g_loss: 1.3171
# Epoch [    5/   15] | d_loss: 1.7014 | g_loss: 1.1031
# Epoch [    5/   15] | d_loss: 0.7752 | g_loss: 1.8832
# Epoch [    5/   15] | d_loss: 0.7839 | g_loss: 1.6453
# Epoch [    5/   15] | d_loss: 1.0939 | g_loss: 1.4063
# Epoch [    5/   15] | d_loss: 0.8133 | g_loss: 1.7912
# Epoch [    5/   15] | d_loss: 0.8282 | g_loss: 1.7901
# Epoch [    5/   15] | d_loss: 1.2474 | g_loss: 1.0748
# Epoch [    5/   15] | d_loss: 0.5665 | g_loss: 2.6287
# Epoch [    5/   15] | d_loss: 0.7131 | g_loss: 2.0792
# Epoch [    5/   15] | d_loss: 0.5997 | g_loss: 2.5220
# Epoch [    5/   15] | d_loss: 1.1868 | g_loss: 2.0216
# Epoch [    5/   15] | d_loss: 0.9575 | g_loss: 1.2483
# Epoch [    5/   15] | d_loss: 0.8709 | g_loss: 1.7121
# Epoch [    5/   15] | d_loss: 0.8726 | g_loss: 1.6453
# Epoch [    5/   15] | d_loss: 0.9953 | g_loss: 1.4716
# Epoch [    5/   15] | d_loss: 0.6028 | g_loss: 1.7764
# Epoch [    5/   15] | d_loss: 0.9759 | g_loss: 1.0968
# Epoch [    5/   15] | d_loss: 1.4344 | g_loss: 1.1479
# Epoch [    5/   15] | d_loss: 0.7297 | g_loss: 1.7100
# Epoch [    5/   15] | d_loss: 1.1169 | g_loss: 1.0151
# Epoch [    5/   15] | d_loss: 0.8477 | g_loss: 1.8745
# Epoch [    5/   15] | d_loss: 0.5981 | g_loss: 2.8201
# Epoch [    5/   15] | d_loss: 0.8059 | g_loss: 2.2160
# Epoch [    5/   15] | d_loss: 1.0162 | g_loss: 1.3957
# Epoch [    5/   15] | d_loss: 0.7156 | g_loss: 2.3481
# Epoch [    5/   15] | d_loss: 1.3927 | g_loss: 1.4396
# Epoch [    5/   15] | d_loss: 1.0501 | g_loss: 1.5628
# Epoch [    5/   15] | d_loss: 0.7821 | g_loss: 2.3651
# Epoch [    5/   15] | d_loss: 0.7974 | g_loss: 1.7898
# Epoch [    5/   15] | d_loss: 0.6079 | g_loss: 2.4956
# Epoch [    5/   15] | d_loss: 0.6411 | g_loss: 2.1943
# Epoch [    5/   15] | d_loss: 0.8951 | g_loss: 1.7468
# Epoch [    5/   15] | d_loss: 0.6118 | g_loss: 2.4242
# Epoch [    5/   15] | d_loss: 0.5836 | g_loss: 2.4635
# Epoch [    5/   15] | d_loss: 0.7926 | g_loss: 2.7067
# Epoch [    5/   15] | d_loss: 0.5493 | g_loss: 2.6305
# Epoch [    5/   15] | d_loss: 0.9007 | g_loss: 1.1993
# Epoch [    5/   15] | d_loss: 0.9510 | g_loss: 1.4382
# Epoch [    5/   15] | d_loss: 1.1412 | g_loss: 1.3695
# Epoch [    5/   15] | d_loss: 0.8176 | g_loss: 2.1828
# Epoch [    5/   15] | d_loss: 0.8272 | g_loss: 2.1244
# Epoch [    5/   15] | d_loss: 0.7404 | g_loss: 1.5947
# Epoch [    5/   15] | d_loss: 0.7088 | g_loss: 2.2525
# Epoch [    5/   15] | d_loss: 0.9585 | g_loss: 1.4614
# Epoch [    5/   15] | d_loss: 1.0761 | g_loss: 1.4140
# Epoch [    5/   15] | d_loss: 0.8289 | g_loss: 2.4744
# Epoch [    5/   15] | d_loss: 0.7271 | g_loss: 1.4630
# Epoch [    5/   15] | d_loss: 1.0484 | g_loss: 1.8562
# Epoch [    5/   15] | d_loss: 1.2326 | g_loss: 1.5329
# Epoch [    5/   15] | d_loss: 0.5920 | g_loss: 2.1050
# Epoch [    5/   15] | d_loss: 0.9722 | g_loss: 2.0626
# Epoch [    5/   15] | d_loss: 0.7735 | g_loss: 1.9958
# Epoch [    5/   15] | d_loss: 0.5990 | g_loss: 2.8866
# Epoch [    5/   15] | d_loss: 0.7301 | g_loss: 2.5702
# Epoch [    5/   15] | d_loss: 0.7015 | g_loss: 2.0157
# Epoch [    5/   15] | d_loss: 0.9352 | g_loss: 2.4997
# Epoch [    5/   15] | d_loss: 0.6664 | g_loss: 1.2785
# Epoch [    5/   15] | d_loss: 0.7154 | g_loss: 2.1904
# Epoch [    5/   15] | d_loss: 0.8385 | g_loss: 1.9567
# Epoch [    6/   15] | d_loss: 1.0093 | g_loss: 1.4511
# Epoch [    6/   15] | d_loss: 0.8694 | g_loss: 1.9610
# Epoch [    6/   15] | d_loss: 0.7218 | g_loss: 2.5157
# Epoch [    6/   15] | d_loss: 0.5088 | g_loss: 2.2894
# Epoch [    6/   15] | d_loss: 1.3324 | g_loss: 1.0008
# Epoch [    6/   15] | d_loss: 1.2073 | g_loss: 1.5467
# Epoch [    6/   15] | d_loss: 1.1149 | g_loss: 1.9630
# Epoch [    6/   15] | d_loss: 0.9318 | g_loss: 2.3346
# Epoch [    6/   15] | d_loss: 1.0456 | g_loss: 1.6476
# Epoch [    6/   15] | d_loss: 0.8522 | g_loss: 1.4657
# Epoch [    6/   15] | d_loss: 0.7334 | g_loss: 2.2873
# Epoch [    6/   15] | d_loss: 0.8302 | g_loss: 2.0848
# Epoch [    6/   15] | d_loss: 0.9767 | g_loss: 1.8909
# Epoch [    6/   15] | d_loss: 0.6026 | g_loss: 2.6992
# Epoch [    6/   15] | d_loss: 0.7278 | g_loss: 2.1100
# Epoch [    6/   15] | d_loss: 0.7776 | g_loss: 1.5884
# Epoch [    6/   15] | d_loss: 0.9825 | g_loss: 1.0705
# Epoch [    6/   15] | d_loss: 1.3965 | g_loss: 1.2219
# Epoch [    6/   15] | d_loss: 0.7626 | g_loss: 1.7170
# Epoch [    6/   15] | d_loss: 0.8744 | g_loss: 2.1054
# Epoch [    6/   15] | d_loss: 0.8658 | g_loss: 2.4489
# Epoch [    6/   15] | d_loss: 0.9753 | g_loss: 1.2700
# Epoch [    6/   15] | d_loss: 0.6619 | g_loss: 2.3280
# Epoch [    6/   15] | d_loss: 1.0507 | g_loss: 1.3656
# Epoch [    6/   15] | d_loss: 0.7323 | g_loss: 2.2619
# Epoch [    6/   15] | d_loss: 1.0266 | g_loss: 1.4141
# Epoch [    6/   15] | d_loss: 0.9150 | g_loss: 2.6695
# Epoch [    6/   15] | d_loss: 0.5097 | g_loss: 2.6753
# Epoch [    6/   15] | d_loss: 0.6574 | g_loss: 3.3137
# Epoch [    6/   15] | d_loss: 0.7238 | g_loss: 2.2671
# Epoch [    6/   15] | d_loss: 0.5983 | g_loss: 1.8500
# Epoch [    6/   15] | d_loss: 0.6873 | g_loss: 2.0643
# Epoch [    6/   15] | d_loss: 1.0311 | g_loss: 1.9137
# Epoch [    6/   15] | d_loss: 0.9585 | g_loss: 1.6687
# Epoch [    6/   15] | d_loss: 0.9141 | g_loss: 1.5822
# Epoch [    6/   15] | d_loss: 0.8535 | g_loss: 2.8696
# Epoch [    6/   15] | d_loss: 1.0988 | g_loss: 1.1695
# Epoch [    6/   15] | d_loss: 1.4448 | g_loss: 2.3278
# Epoch [    6/   15] | d_loss: 1.1402 | g_loss: 1.3331
# Epoch [    6/   15] | d_loss: 0.8644 | g_loss: 2.2782
# Epoch [    6/   15] | d_loss: 0.9228 | g_loss: 1.4766
# Epoch [    6/   15] | d_loss: 1.3656 | g_loss: 1.1181
# Epoch [    6/   15] | d_loss: 0.6365 | g_loss: 2.4871
# Epoch [    6/   15] | d_loss: 1.9712 | g_loss: 1.0137
# Epoch [    6/   15] | d_loss: 0.5407 | g_loss: 2.4439
# Epoch [    6/   15] | d_loss: 0.5418 | g_loss: 2.2170
# Epoch [    6/   15] | d_loss: 0.8745 | g_loss: 2.5331
# Epoch [    6/   15] | d_loss: 0.5301 | g_loss: 2.3877
# Epoch [    6/   15] | d_loss: 0.6381 | g_loss: 2.5119
# Epoch [    6/   15] | d_loss: 1.5214 | g_loss: 1.4414
# Epoch [    6/   15] | d_loss: 0.7400 | g_loss: 1.9948
# Epoch [    6/   15] | d_loss: 1.1332 | g_loss: 1.7583
# Epoch [    6/   15] | d_loss: 1.1036 | g_loss: 1.3892
# Epoch [    6/   15] | d_loss: 1.5020 | g_loss: 0.9811
# Epoch [    6/   15] | d_loss: 0.5685 | g_loss: 2.7551
# Epoch [    6/   15] | d_loss: 0.9625 | g_loss: 1.6730
# Epoch [    6/   15] | d_loss: 1.0934 | g_loss: 1.3084
# Epoch [    6/   15] | d_loss: 0.7605 | g_loss: 1.8724
# Epoch [    6/   15] | d_loss: 0.6489 | g_loss: 2.3317
# Epoch [    6/   15] | d_loss: 0.6087 | g_loss: 1.8508
# Epoch [    6/   15] | d_loss: 0.7368 | g_loss: 2.1555
# Epoch [    6/   15] | d_loss: 0.9776 | g_loss: 1.7106
# Epoch [    6/   15] | d_loss: 0.9223 | g_loss: 1.6763
# Epoch [    6/   15] | d_loss: 0.6722 | g_loss: 1.7577
# Epoch [    6/   15] | d_loss: 0.6297 | g_loss: 1.4720
# Epoch [    6/   15] | d_loss: 1.0176 | g_loss: 1.7970
# Epoch [    6/   15] | d_loss: 0.5964 | g_loss: 2.5790
# Epoch [    6/   15] | d_loss: 0.4583 | g_loss: 2.9004
# Epoch [    6/   15] | d_loss: 0.8776 | g_loss: 1.9399
# Epoch [    6/   15] | d_loss: 1.1009 | g_loss: 2.1446
# Epoch [    6/   15] | d_loss: 0.6032 | g_loss: 2.6377
# Epoch [    6/   15] | d_loss: 0.7306 | g_loss: 2.2430
# Epoch [    6/   15] | d_loss: 0.5431 | g_loss: 3.1646
# Epoch [    6/   15] | d_loss: 0.8336 | g_loss: 1.5439
# Epoch [    6/   15] | d_loss: 0.7627 | g_loss: 2.4124
# Epoch [    6/   15] | d_loss: 0.5049 | g_loss: 2.7833
# Epoch [    6/   15] | d_loss: 0.7450 | g_loss: 2.0006
# Epoch [    6/   15] | d_loss: 0.4460 | g_loss: 3.1348
# Epoch [    6/   15] | d_loss: 0.7268 | g_loss: 1.6692
# Epoch [    6/   15] | d_loss: 0.5598 | g_loss: 2.4332
# Epoch [    6/   15] | d_loss: 0.6181 | g_loss: 2.1062
# Epoch [    6/   15] | d_loss: 0.6145 | g_loss: 2.7915
# Epoch [    6/   15] | d_loss: 0.6674 | g_loss: 2.9437
# Epoch [    6/   15] | d_loss: 0.7394 | g_loss: 2.6129
# Epoch [    6/   15] | d_loss: 0.9288 | g_loss: 0.8444
# Epoch [    6/   15] | d_loss: 1.0112 | g_loss: 2.5580
# Epoch [    6/   15] | d_loss: 0.9852 | g_loss: 1.4374
# Epoch [    6/   15] | d_loss: 0.6476 | g_loss: 2.4844
# Epoch [    6/   15] | d_loss: 0.5751 | g_loss: 2.3257
# Epoch [    6/   15] | d_loss: 0.6886 | g_loss: 2.1159
# Epoch [    6/   15] | d_loss: 0.6024 | g_loss: 2.3381
# Epoch [    6/   15] | d_loss: 1.1163 | g_loss: 1.2031
# Epoch [    6/   15] | d_loss: 1.1722 | g_loss: 1.9906
# Epoch [    6/   15] | d_loss: 0.6754 | g_loss: 2.1384
# Epoch [    6/   15] | d_loss: 0.9234 | g_loss: 1.8679
# Epoch [    6/   15] | d_loss: 0.9009 | g_loss: 2.4190
# Epoch [    6/   15] | d_loss: 1.0042 | g_loss: 1.5629
# Epoch [    6/   15] | d_loss: 0.6184 | g_loss: 2.5104
# Epoch [    6/   15] | d_loss: 0.7063 | g_loss: 2.0349
# Epoch [    6/   15] | d_loss: 0.6569 | g_loss: 2.1981
# Epoch [    6/   15] | d_loss: 0.5315 | g_loss: 2.0248
# Epoch [    6/   15] | d_loss: 0.8209 | g_loss: 1.8054
# Epoch [    6/   15] | d_loss: 1.0759 | g_loss: 1.4065
# Epoch [    6/   15] | d_loss: 0.7711 | g_loss: 2.7497
# Epoch [    6/   15] | d_loss: 0.9094 | g_loss: 1.9905
# Epoch [    6/   15] | d_loss: 0.6140 | g_loss: 1.9716
# Epoch [    6/   15] | d_loss: 0.6819 | g_loss: 2.2410
# Epoch [    6/   15] | d_loss: 0.6566 | g_loss: 1.8916
# Epoch [    6/   15] | d_loss: 0.5728 | g_loss: 2.5346
# Epoch [    6/   15] | d_loss: 1.0311 | g_loss: 1.4623
# Epoch [    6/   15] | d_loss: 0.6596 | g_loss: 2.0257
# Epoch [    6/   15] | d_loss: 0.8075 | g_loss: 1.3260
# Epoch [    6/   15] | d_loss: 0.6726 | g_loss: 2.7297
# Epoch [    7/   15] | d_loss: 0.7334 | g_loss: 2.2677
# Epoch [    7/   15] | d_loss: 0.6093 | g_loss: 2.7180
# Epoch [    7/   15] | d_loss: 0.7652 | g_loss: 1.4522
# Epoch [    7/   15] | d_loss: 1.0251 | g_loss: 1.3758
# Epoch [    7/   15] | d_loss: 1.1141 | g_loss: 1.7811
# Epoch [    7/   15] | d_loss: 0.7075 | g_loss: 2.6167
# Epoch [    7/   15] | d_loss: 1.1048 | g_loss: 1.5030
# Epoch [    7/   15] | d_loss: 0.9822 | g_loss: 1.9728
# Epoch [    7/   15] | d_loss: 1.0941 | g_loss: 1.6434
# Epoch [    7/   15] | d_loss: 0.9012 | g_loss: 1.9566
# Epoch [    7/   15] | d_loss: 1.0566 | g_loss: 2.0524
# Epoch [    7/   15] | d_loss: 0.9370 | g_loss: 2.0267
# Epoch [    7/   15] | d_loss: 0.6811 | g_loss: 2.6823
# Epoch [    7/   15] | d_loss: 0.8102 | g_loss: 2.3126
# Epoch [    7/   15] | d_loss: 0.4938 | g_loss: 2.5756
# Epoch [    7/   15] | d_loss: 0.7605 | g_loss: 2.9471
# Epoch [    7/   15] | d_loss: 1.7670 | g_loss: 1.7228
# Epoch [    7/   15] | d_loss: 0.7264 | g_loss: 3.1065
# Epoch [    7/   15] | d_loss: 0.9496 | g_loss: 2.0769
# Epoch [    7/   15] | d_loss: 0.7958 | g_loss: 2.0838
# Epoch [    7/   15] | d_loss: 0.8864 | g_loss: 2.7502
# Epoch [    7/   15] | d_loss: 0.7225 | g_loss: 1.8594
# Epoch [    7/   15] | d_loss: 0.6251 | g_loss: 2.3201
# Epoch [    7/   15] | d_loss: 0.5315 | g_loss: 2.7226
# Epoch [    7/   15] | d_loss: 0.5526 | g_loss: 2.3120
# Epoch [    7/   15] | d_loss: 0.6563 | g_loss: 2.1458
# Epoch [    7/   15] | d_loss: 1.0718 | g_loss: 1.7827
# Epoch [    7/   15] | d_loss: 1.1843 | g_loss: 2.3255
# Epoch [    7/   15] | d_loss: 0.6114 | g_loss: 2.8797
# Epoch [    7/   15] | d_loss: 0.5984 | g_loss: 2.4413
# Epoch [    7/   15] | d_loss: 0.6103 | g_loss: 2.7833
# Epoch [    7/   15] | d_loss: 0.5126 | g_loss: 2.8506
# Epoch [    7/   15] | d_loss: 0.5323 | g_loss: 3.0523
# Epoch [    7/   15] | d_loss: 0.6577 | g_loss: 2.4107
# Epoch [    7/   15] | d_loss: 0.6176 | g_loss: 2.6889
# Epoch [    7/   15] | d_loss: 0.6407 | g_loss: 1.7773
# Epoch [    7/   15] | d_loss: 0.7146 | g_loss: 2.4120
# Epoch [    7/   15] | d_loss: 0.9246 | g_loss: 2.7136
# Epoch [    7/   15] | d_loss: 0.8254 | g_loss: 2.0148
# Epoch [    7/   15] | d_loss: 0.4950 | g_loss: 2.8195
# Epoch [    7/   15] | d_loss: 0.7892 | g_loss: 2.3603
# Epoch [    7/   15] | d_loss: 0.7160 | g_loss: 1.9731
# Epoch [    7/   15] | d_loss: 0.6331 | g_loss: 2.2463
# Epoch [    7/   15] | d_loss: 1.0047 | g_loss: 2.7018
# Epoch [    7/   15] | d_loss: 0.6025 | g_loss: 2.4239
# Epoch [    7/   15] | d_loss: 0.6525 | g_loss: 2.6784
# Epoch [    7/   15] | d_loss: 1.0294 | g_loss: 1.5513
# Epoch [    7/   15] | d_loss: 0.8825 | g_loss: 1.5101
# Epoch [    7/   15] | d_loss: 1.3112 | g_loss: 1.8565
# Epoch [    7/   15] | d_loss: 0.6681 | g_loss: 2.2712
# Epoch [    7/   15] | d_loss: 0.7701 | g_loss: 1.8570
# Epoch [    7/   15] | d_loss: 0.8749 | g_loss: 1.6728
# Epoch [    7/   15] | d_loss: 0.9804 | g_loss: 1.3048
# Epoch [    7/   15] | d_loss: 0.9818 | g_loss: 1.8687
# Epoch [    7/   15] | d_loss: 0.9154 | g_loss: 1.7166
# Epoch [    7/   15] | d_loss: 0.5092 | g_loss: 2.9874
# Epoch [    7/   15] | d_loss: 1.1338 | g_loss: 1.3471
# Epoch [    7/   15] | d_loss: 0.9052 | g_loss: 1.9703
# Epoch [    7/   15] | d_loss: 0.5751 | g_loss: 2.3833
# Epoch [    7/   15] | d_loss: 0.7231 | g_loss: 1.9818
# Epoch [    7/   15] | d_loss: 0.6969 | g_loss: 2.1430
# Epoch [    7/   15] | d_loss: 0.7074 | g_loss: 2.3970
# Epoch [    7/   15] | d_loss: 0.5441 | g_loss: 3.2371
# Epoch [    7/   15] | d_loss: 0.6820 | g_loss: 1.9220
# Epoch [    7/   15] | d_loss: 0.9713 | g_loss: 1.7670
# Epoch [    7/   15] | d_loss: 1.0680 | g_loss: 1.5357
# Epoch [    7/   15] | d_loss: 1.4648 | g_loss: 1.6218
# Epoch [    7/   15] | d_loss: 0.9406 | g_loss: 2.5528
# Epoch [    7/   15] | d_loss: 1.0885 | g_loss: 1.3199
# Epoch [    7/   15] | d_loss: 0.8035 | g_loss: 2.2844
# Epoch [    7/   15] | d_loss: 0.5982 | g_loss: 3.1613
# Epoch [    7/   15] | d_loss: 1.0290 | g_loss: 1.2625
# Epoch [    7/   15] | d_loss: 0.5363 | g_loss: 2.3029
# Epoch [    7/   15] | d_loss: 0.4985 | g_loss: 3.3767
# Epoch [    7/   15] | d_loss: 1.6042 | g_loss: 2.0330
# Epoch [    7/   15] | d_loss: 0.6901 | g_loss: 2.0490
# Epoch [    7/   15] | d_loss: 0.5491 | g_loss: 2.4390
# Epoch [    7/   15] | d_loss: 0.6148 | g_loss: 2.0968
# Epoch [    7/   15] | d_loss: 0.6782 | g_loss: 2.3277
# Epoch [    7/   15] | d_loss: 0.9236 | g_loss: 1.4139
# Epoch [    7/   15] | d_loss: 0.9524 | g_loss: 2.7370
# Epoch [    7/   15] | d_loss: 0.7490 | g_loss: 2.2400
# Epoch [    7/   15] | d_loss: 0.9107 | g_loss: 1.6936
# Epoch [    7/   15] | d_loss: 0.5271 | g_loss: 2.4283
# Epoch [    7/   15] | d_loss: 0.9791 | g_loss: 1.9581
# Epoch [    7/   15] | d_loss: 0.6079 | g_loss: 2.2625
# Epoch [    7/   15] | d_loss: 0.5266 | g_loss: 2.9895
# Epoch [    7/   15] | d_loss: 0.8965 | g_loss: 1.8763
# Epoch [    7/   15] | d_loss: 0.5491 | g_loss: 2.8857
# Epoch [    7/   15] | d_loss: 0.4881 | g_loss: 2.8873
# Epoch [    7/   15] | d_loss: 0.7499 | g_loss: 2.3199
# Epoch [    7/   15] | d_loss: 0.5152 | g_loss: 2.1825
# Epoch [    7/   15] | d_loss: 0.7217 | g_loss: 2.6832
# Epoch [    7/   15] | d_loss: 0.5959 | g_loss: 2.4718
# Epoch [    7/   15] | d_loss: 0.9227 | g_loss: 2.6877
# Epoch [    7/   15] | d_loss: 0.6635 | g_loss: 1.5975
# Epoch [    7/   15] | d_loss: 0.8395 | g_loss: 1.3010
# Epoch [    7/   15] | d_loss: 0.6115 | g_loss: 2.3385
# Epoch [    7/   15] | d_loss: 0.6319 | g_loss: 2.0300
# Epoch [    7/   15] | d_loss: 0.7524 | g_loss: 2.3438
# Epoch [    7/   15] | d_loss: 0.8467 | g_loss: 2.0049
# Epoch [    7/   15] | d_loss: 0.6815 | g_loss: 2.1042
# Epoch [    7/   15] | d_loss: 0.7760 | g_loss: 1.6466
# Epoch [    7/   15] | d_loss: 0.5949 | g_loss: 2.2664
# Epoch [    7/   15] | d_loss: 0.4716 | g_loss: 3.6207
# Epoch [    7/   15] | d_loss: 1.0308 | g_loss: 2.0317
# Epoch [    7/   15] | d_loss: 0.7355 | g_loss: 2.2867
# Epoch [    7/   15] | d_loss: 0.7593 | g_loss: 1.4082
# Epoch [    7/   15] | d_loss: 0.9512 | g_loss: 2.1491
# Epoch [    7/   15] | d_loss: 0.7728 | g_loss: 1.7858
# Epoch [    7/   15] | d_loss: 0.8763 | g_loss: 2.1563
# Epoch [    7/   15] | d_loss: 0.6619 | g_loss: 2.4784
# Epoch [    7/   15] | d_loss: 0.6487 | g_loss: 2.2239
# Epoch [    8/   15] | d_loss: 0.5548 | g_loss: 2.3647
# Epoch [    8/   15] | d_loss: 1.0144 | g_loss: 1.4591
# Epoch [    8/   15] | d_loss: 0.4971 | g_loss: 2.6564
# Epoch [    8/   15] | d_loss: 0.5285 | g_loss: 3.5282
# Epoch [    8/   15] | d_loss: 1.0950 | g_loss: 0.7726
# Epoch [    8/   15] | d_loss: 0.9803 | g_loss: 2.6113
# Epoch [    8/   15] | d_loss: 0.6866 | g_loss: 2.5245
# Epoch [    8/   15] | d_loss: 1.1248 | g_loss: 1.0843
# Epoch [    8/   15] | d_loss: 1.2118 | g_loss: 2.4147
# Epoch [    8/   15] | d_loss: 0.4871 | g_loss: 3.2516
# Epoch [    8/   15] | d_loss: 1.5313 | g_loss: 1.1853
# Epoch [    8/   15] | d_loss: 0.6571 | g_loss: 2.0673
# Epoch [    8/   15] | d_loss: 0.7786 | g_loss: 2.1556
# Epoch [    8/   15] | d_loss: 0.8064 | g_loss: 2.5906
# Epoch [    8/   15] | d_loss: 3.3594 | g_loss: 1.4684
# Epoch [    8/   15] | d_loss: 1.3443 | g_loss: 1.8842
# Epoch [    8/   15] | d_loss: 0.9486 | g_loss: 1.7149
# Epoch [    8/   15] | d_loss: 0.9036 | g_loss: 1.4017
# Epoch [    8/   15] | d_loss: 1.0583 | g_loss: 1.4993
# Epoch [    8/   15] | d_loss: 0.8132 | g_loss: 2.1356
# Epoch [    8/   15] | d_loss: 0.5291 | g_loss: 2.8102
# Epoch [    8/   15] | d_loss: 0.7032 | g_loss: 2.4916
# Epoch [    8/   15] | d_loss: 0.6465 | g_loss: 2.1664
# Epoch [    8/   15] | d_loss: 0.6333 | g_loss: 2.9190
# Epoch [    8/   15] | d_loss: 0.9757 | g_loss: 1.8031
# Epoch [    8/   15] | d_loss: 0.6201 | g_loss: 3.2904
# Epoch [    8/   15] | d_loss: 1.1579 | g_loss: 1.5901
# Epoch [    8/   15] | d_loss: 0.5280 | g_loss: 2.4058
# Epoch [    8/   15] | d_loss: 1.1351 | g_loss: 2.0559
# Epoch [    8/   15] | d_loss: 0.5892 | g_loss: 2.6612
# Epoch [    8/   15] | d_loss: 0.9123 | g_loss: 1.9138
# Epoch [    8/   15] | d_loss: 0.9744 | g_loss: 2.0017
# Epoch [    8/   15] | d_loss: 0.9316 | g_loss: 1.5190
# Epoch [    8/   15] | d_loss: 0.7918 | g_loss: 1.4660
# Epoch [    8/   15] | d_loss: 0.5920 | g_loss: 3.3583
# Epoch [    8/   15] | d_loss: 0.8078 | g_loss: 2.5935
# Epoch [    8/   15] | d_loss: 0.5759 | g_loss: 1.8098
# Epoch [    8/   15] | d_loss: 1.1175 | g_loss: 2.6489
# Epoch [    8/   15] | d_loss: 0.6334 | g_loss: 2.7028
# Epoch [    8/   15] | d_loss: 0.8371 | g_loss: 1.6776
# Epoch [    8/   15] | d_loss: 0.5278 | g_loss: 2.7922
# Epoch [    8/   15] | d_loss: 0.4961 | g_loss: 2.7595
# Epoch [    8/   15] | d_loss: 0.7688 | g_loss: 2.8113
# Epoch [    8/   15] | d_loss: 1.1087 | g_loss: 1.7263
# Epoch [    8/   15] | d_loss: 0.7942 | g_loss: 2.2182
# Epoch [    8/   15] | d_loss: 0.5717 | g_loss: 2.0181
# Epoch [    8/   15] | d_loss: 0.8583 | g_loss: 2.1371
# Epoch [    8/   15] | d_loss: 0.4784 | g_loss: 2.2681
# Epoch [    8/   15] | d_loss: 0.6932 | g_loss: 2.0500
# Epoch [    8/   15] | d_loss: 0.9102 | g_loss: 1.8602
# Epoch [    8/   15] | d_loss: 0.6141 | g_loss: 3.1421
# Epoch [    8/   15] | d_loss: 0.6932 | g_loss: 2.7475
# Epoch [    8/   15] | d_loss: 0.8353 | g_loss: 1.3034
# Epoch [    8/   15] | d_loss: 0.8241 | g_loss: 1.5081
# Epoch [    8/   15] | d_loss: 0.6509 | g_loss: 2.3361
# Epoch [    8/   15] | d_loss: 0.4804 | g_loss: 3.3560
# Epoch [    8/   15] | d_loss: 0.7800 | g_loss: 2.0361
# Epoch [    8/   15] | d_loss: 0.5448 | g_loss: 2.0985
# Epoch [    8/   15] | d_loss: 0.7444 | g_loss: 1.8387
# Epoch [    8/   15] | d_loss: 1.0134 | g_loss: 1.5087
# Epoch [    8/   15] | d_loss: 0.9601 | g_loss: 1.7474
# Epoch [    8/   15] | d_loss: 0.9261 | g_loss: 1.7086
# Epoch [    8/   15] | d_loss: 0.6451 | g_loss: 3.3680
# Epoch [    8/   15] | d_loss: 0.7211 | g_loss: 2.0621
# Epoch [    8/   15] | d_loss: 1.1511 | g_loss: 1.9578
# Epoch [    8/   15] | d_loss: 0.8460 | g_loss: 1.6522
# Epoch [    8/   15] | d_loss: 1.4838 | g_loss: 1.3754
# Epoch [    8/   15] | d_loss: 0.6236 | g_loss: 2.9653
# Epoch [    8/   15] | d_loss: 1.0201 | g_loss: 2.1324
# Epoch [    8/   15] | d_loss: 0.8407 | g_loss: 2.8052
# Epoch [    8/   15] | d_loss: 0.9412 | g_loss: 1.7005
# Epoch [    8/   15] | d_loss: 0.7696 | g_loss: 2.0255
# Epoch [    8/   15] | d_loss: 0.7814 | g_loss: 2.5882
# Epoch [    8/   15] | d_loss: 0.7259 | g_loss: 2.5715
# Epoch [    8/   15] | d_loss: 0.6184 | g_loss: 2.1110
# Epoch [    8/   15] | d_loss: 0.7382 | g_loss: 2.1158
# Epoch [    8/   15] | d_loss: 0.5562 | g_loss: 3.0592
# Epoch [    8/   15] | d_loss: 0.6522 | g_loss: 2.1990
# Epoch [    8/   15] | d_loss: 0.8822 | g_loss: 1.9549
# Epoch [    8/   15] | d_loss: 1.1953 | g_loss: 1.8081
# Epoch [    8/   15] | d_loss: 0.6031 | g_loss: 2.1391
# Epoch [    8/   15] | d_loss: 0.6989 | g_loss: 2.7455
# Epoch [    8/   15] | d_loss: 0.6027 | g_loss: 1.8394
# Epoch [    8/   15] | d_loss: 1.2200 | g_loss: 1.7663
# Epoch [    8/   15] | d_loss: 0.6967 | g_loss: 2.8040
# Epoch [    8/   15] | d_loss: 0.6874 | g_loss: 2.6028
# Epoch [    8/   15] | d_loss: 0.7515 | g_loss: 2.9971
# Epoch [    8/   15] | d_loss: 0.8455 | g_loss: 2.0701
# Epoch [    8/   15] | d_loss: 2.4015 | g_loss: 1.4517
# Epoch [    8/   15] | d_loss: 0.8099 | g_loss: 2.5442
# Epoch [    8/   15] | d_loss: 0.6286 | g_loss: 2.3378
# Epoch [    8/   15] | d_loss: 0.5475 | g_loss: 2.8210
# Epoch [    8/   15] | d_loss: 0.7399 | g_loss: 1.9997
# Epoch [    8/   15] | d_loss: 0.9267 | g_loss: 2.4511
# Epoch [    8/   15] | d_loss: 0.7815 | g_loss: 2.8019
# Epoch [    8/   15] | d_loss: 0.9055 | g_loss: 1.3823
# Epoch [    8/   15] | d_loss: 0.4896 | g_loss: 2.2147
# ...
# Epoch [   13/   15] | d_loss: 0.5294 | g_loss: 2.2837
# Epoch [   13/   15] | d_loss: 0.5489 | g_loss: 2.5487
# Epoch [   13/   15] | d_loss: 0.7440 | g_loss: 1.8908
# Epoch [   13/   15] | d_loss: 0.5239 | g_loss: 2.9352
# Epoch [   13/   15] | d_loss: 0.9818 | g_loss: 1.8261
# Epoch [   13/   15] | d_loss: 0.6565 | g_loss: 2.5267
# Epoch [   13/   15] | d_loss: 0.5819 | g_loss: 2.4564
# Epoch [   13/   15] | d_loss: 0.7387 | g_loss: 2.7225
# Epoch [   13/   15] | d_loss: 0.6654 | g_loss: 3.5643
# Epoch [   13/   15] | d_loss: 0.8257 | g_loss: 2.5425
# Epoch [   13/   15] | d_loss: 0.6138 | g_loss: 2.2598
# Epoch [   13/   15] | d_loss: 0.6207 | g_loss: 2.5011
# Epoch [   13/   15] | d_loss: 0.4513 | g_loss: 3.2396
# Epoch [   13/   15] | d_loss: 0.6120 | g_loss: 3.1105
# Epoch [   13/   15] | d_loss: 0.5125 | g_loss: 3.3577
# Epoch [   13/   15] | d_loss: 0.9276 | g_loss: 1.5227
# Epoch [   13/   15] | d_loss: 0.4432 | g_loss: 3.7473
# Epoch [   13/   15] | d_loss: 0.6481 | g_loss: 2.8995
# Epoch [   13/   15] | d_loss: 0.4100 | g_loss: 3.1891
# Epoch [   13/   15] | d_loss: 0.7590 | g_loss: 3.3388
# Epoch [   13/   15] | d_loss: 0.4386 | g_loss: 3.7074
# Epoch [   13/   15] | d_loss: 0.8600 | g_loss: 2.3629
# Epoch [   13/   15] | d_loss: 0.5208 | g_loss: 3.3775
# Epoch [   13/   15] | d_loss: 0.5056 | g_loss: 3.2055
# Epoch [   13/   15] | d_loss: 0.7976 | g_loss: 2.1565
# Epoch [   13/   15] | d_loss: 0.5502 | g_loss: 2.6484
# Epoch [   13/   15] | d_loss: 0.6004 | g_loss: 2.8354
# Epoch [   13/   15] | d_loss: 0.5108 | g_loss: 3.8350
# Epoch [   13/   15] | d_loss: 0.5136 | g_loss: 3.7599
# Epoch [   13/   15] | d_loss: 0.6384 | g_loss: 3.4063
# Epoch [   13/   15] | d_loss: 0.4329 | g_loss: 4.0604
# Epoch [   13/   15] | d_loss: 0.6851 | g_loss: 2.9516
# Epoch [   13/   15] | d_loss: 0.4851 | g_loss: 3.5400
# Epoch [   13/   15] | d_loss: 0.6386 | g_loss: 2.9498
# Epoch [   13/   15] | d_loss: 1.1046 | g_loss: 1.4791
# Epoch [   13/   15] | d_loss: 0.6330 | g_loss: 3.1744
# Epoch [   13/   15] | d_loss: 0.4569 | g_loss: 2.6305
# Epoch [   13/   15] | d_loss: 0.5015 | g_loss: 3.4042
# Epoch [   13/   15] | d_loss: 0.4316 | g_loss: 2.9137
# Epoch [   13/   15] | d_loss: 0.5013 | g_loss: 3.7861
# Epoch [   13/   15] | d_loss: 0.4163 | g_loss: 3.3678
# Epoch [   13/   15] | d_loss: 0.4925 | g_loss: 2.8202
# Epoch [   13/   15] | d_loss: 0.4062 | g_loss: 3.8498
# Epoch [   13/   15] | d_loss: 0.4763 | g_loss: 3.3502
# Epoch [   13/   15] | d_loss: 0.7330 | g_loss: 2.2409
# Epoch [   13/   15] | d_loss: 0.5686 | g_loss: 2.4298
# Epoch [   13/   15] | d_loss: 0.5594 | g_loss: 3.2854
# Epoch [   13/   15] | d_loss: 0.6435 | g_loss: 2.0614
# Epoch [   13/   15] | d_loss: 1.0784 | g_loss: 3.3073
# Epoch [   13/   15] | d_loss: 0.4589 | g_loss: 3.2329
# Epoch [   13/   15] | d_loss: 0.4764 | g_loss: 2.7226
# Epoch [   13/   15] | d_loss: 1.1007 | g_loss: 2.0492
# Epoch [   13/   15] | d_loss: 0.8761 | g_loss: 3.5020
# Epoch [   13/   15] | d_loss: 0.6341 | g_loss: 3.0699
# Epoch [   13/   15] | d_loss: 0.6233 | g_loss: 2.8699
# Epoch [   13/   15] | d_loss: 0.5804 | g_loss: 2.8877
# Epoch [   13/   15] | d_loss: 0.5900 | g_loss: 2.8262
# Epoch [   13/   15] | d_loss: 0.9204 | g_loss: 2.2346
# Epoch [   13/   15] | d_loss: 0.5909 | g_loss: 2.7212
# Epoch [   13/   15] | d_loss: 0.4727 | g_loss: 3.3768
# Epoch [   13/   15] | d_loss: 0.7320 | g_loss: 3.8784
# Epoch [   13/   15] | d_loss: 0.5120 | g_loss: 3.2935
# Epoch [   13/   15] | d_loss: 0.4514 | g_loss: 3.1633
# Epoch [   13/   15] | d_loss: 0.6269 | g_loss: 2.4731
# Epoch [   13/   15] | d_loss: 0.4439 | g_loss: 3.7574
# Epoch [   13/   15] | d_loss: 0.5526 | g_loss: 3.1671
# Epoch [   13/   15] | d_loss: 0.5091 | g_loss: 3.2792
# Epoch [   13/   15] | d_loss: 0.6037 | g_loss: 3.1337
# Epoch [   13/   15] | d_loss: 0.7058 | g_loss: 3.3249
# Epoch [   13/   15] | d_loss: 0.4953 | g_loss: 2.8526
# Epoch [   14/   15] | d_loss: 0.8358 | g_loss: 2.2465
# Epoch [   14/   15] | d_loss: 0.5800 | g_loss: 3.1548
# Epoch [   14/   15] | d_loss: 0.9840 | g_loss: 1.6620
# Epoch [   14/   15] | d_loss: 0.7288 | g_loss: 2.8129
# Epoch [   14/   15] | d_loss: 0.6655 | g_loss: 2.4998
# Epoch [   14/   15] | d_loss: 0.5236 | g_loss: 3.4270
# Epoch [   14/   15] | d_loss: 0.5974 | g_loss: 3.1106
# Epoch [   14/   15] | d_loss: 0.5156 | g_loss: 3.7071
# Epoch [   14/   15] | d_loss: 0.7111 | g_loss: 3.5986
# Epoch [   14/   15] | d_loss: 0.5829 | g_loss: 2.4518
# Epoch [   14/   15] | d_loss: 0.5901 | g_loss: 2.6773
# Epoch [   14/   15] | d_loss: 1.1082 | g_loss: 2.0276
# Epoch [   14/   15] | d_loss: 0.6988 | g_loss: 3.4616
# Epoch [   14/   15] | d_loss: 0.7507 | g_loss: 3.2508
# Epoch [   14/   15] | d_loss: 0.4943 | g_loss: 3.0842
# Epoch [   14/   15] | d_loss: 0.6531 | g_loss: 2.7834
# Epoch [   14/   15] | d_loss: 0.5986 | g_loss: 1.6213
# Epoch [   14/   15] | d_loss: 0.5072 | g_loss: 3.0949
# Epoch [   14/   15] | d_loss: 0.6223 | g_loss: 2.8182
# Epoch [   14/   15] | d_loss: 0.5680 | g_loss: 2.1742
# Epoch [   14/   15] | d_loss: 0.5125 | g_loss: 2.8975
# Epoch [   14/   15] | d_loss: 0.8825 | g_loss: 2.7379
# Epoch [   14/   15] | d_loss: 0.4791 | g_loss: 2.2774
# Epoch [   14/   15] | d_loss: 0.5576 | g_loss: 2.9949
# Epoch [   14/   15] | d_loss: 0.4731 | g_loss: 3.2455
# Epoch [   14/   15] | d_loss: 0.7946 | g_loss: 3.0307
# Epoch [   14/   15] | d_loss: 0.5983 | g_loss: 2.0967
# Epoch [   14/   15] | d_loss: 0.7763 | g_loss: 2.9118
# Epoch [   14/   15] | d_loss: 0.5316 | g_loss: 3.1158
# Epoch [   14/   15] | d_loss: 0.5079 | g_loss: 3.4632
# Epoch [   14/   15] | d_loss: 0.5392 | g_loss: 3.4293
# Epoch [   14/   15] | d_loss: 0.4912 | g_loss: 3.0590
# Epoch [   14/   15] | d_loss: 0.6510 | g_loss: 2.2578
# Epoch [   14/   15] | d_loss: 0.4042 | g_loss: 3.7776
# Epoch [   14/   15] | d_loss: 0.6859 | g_loss: 2.7303
# Epoch [   14/   15] | d_loss: 0.4431 | g_loss: 3.7635
# Epoch [   14/   15] | d_loss: 0.4565 | g_loss: 3.5329
# Epoch [   14/   15] | d_loss: 0.6279 | g_loss: 2.0451
# Epoch [   14/   15] | d_loss: 0.5116 | g_loss: 3.0275
# Epoch [   14/   15] | d_loss: 0.7003 | g_loss: 2.3869
# Epoch [   14/   15] | d_loss: 0.4506 | g_loss: 3.4531
# Epoch [   14/   15] | d_loss: 0.5238 | g_loss: 3.2014
# Epoch [   14/   15] | d_loss: 0.9334 | g_loss: 1.3486
# Epoch [   14/   15] | d_loss: 0.5848 | g_loss: 3.6768
# Epoch [   14/   15] | d_loss: 0.4666 | g_loss: 3.6893
# Epoch [   14/   15] | d_loss: 1.0661 | g_loss: 0.9940
# Epoch [   14/   15] | d_loss: 0.7000 | g_loss: 2.1402
# Epoch [   14/   15] | d_loss: 0.6680 | g_loss: 3.3288
# Epoch [   14/   15] | d_loss: 0.6935 | g_loss: 2.0495
# Epoch [   14/   15] | d_loss: 0.5033 | g_loss: 2.8058
# Epoch [   14/   15] | d_loss: 0.6175 | g_loss: 1.5325
# Epoch [   14/   15] | d_loss: 0.6061 | g_loss: 3.3973
# Epoch [   14/   15] | d_loss: 0.5062 | g_loss: 3.6410
# Epoch [   14/   15] | d_loss: 0.5201 | g_loss: 3.4083
# Epoch [   14/   15] | d_loss: 0.5162 | g_loss: 3.8183
# Epoch [   14/   15] | d_loss: 0.5873 | g_loss: 2.4586
# Epoch [   14/   15] | d_loss: 0.7585 | g_loss: 1.6738
# Epoch [   14/   15] | d_loss: 1.0021 | g_loss: 1.1676
# Epoch [   14/   15] | d_loss: 0.7470 | g_loss: 3.3137
# Epoch [   14/   15] | d_loss: 0.8151 | g_loss: 2.2252
# Epoch [   14/   15] | d_loss: 0.4256 | g_loss: 3.4033
# Epoch [   14/   15] | d_loss: 0.5407 | g_loss: 3.6628
# Epoch [   14/   15] | d_loss: 0.5156 | g_loss: 3.2854
# Epoch [   14/   15] | d_loss: 0.6159 | g_loss: 3.6874
# Epoch [   14/   15] | d_loss: 0.5800 | g_loss: 2.5944
# Epoch [   14/   15] | d_loss: 0.5513 | g_loss: 3.8344
# Epoch [   14/   15] | d_loss: 1.0065 | g_loss: 3.2200
# Epoch [   14/   15] | d_loss: 0.6921 | g_loss: 2.5224
# Epoch [   14/   15] | d_loss: 0.4670 | g_loss: 3.1001
# Epoch [   14/   15] | d_loss: 0.8516 | g_loss: 1.9053
# Epoch [   14/   15] | d_loss: 0.8958 | g_loss: 2.1465
# Epoch [   14/   15] | d_loss: 0.7834 | g_loss: 3.8910
# Epoch [   14/   15] | d_loss: 0.4043 | g_loss: 3.0456
# Epoch [   14/   15] | d_loss: 0.4890 | g_loss: 3.0502
# Epoch [   14/   15] | d_loss: 0.6924 | g_loss: 2.5614
# Epoch [   14/   15] | d_loss: 0.4724 | g_loss: 3.0566
# Epoch [   14/   15] | d_loss: 0.5099 | g_loss: 2.7945
# Epoch [   14/   15] | d_loss: 0.6474 | g_loss: 2.9951
# Epoch [   14/   15] | d_loss: 0.6071 | g_loss: 3.1947
# Epoch [   14/   15] | d_loss: 0.6305 | g_loss: 2.2845
# Epoch [   14/   15] | d_loss: 0.6044 | g_loss: 2.5982
# Epoch [   14/   15] | d_loss: 0.4508 | g_loss: 3.6405
# Epoch [   14/   15] | d_loss: 0.4853 | g_loss: 2.9565
# Epoch [   14/   15] | d_loss: 0.5428 | g_loss: 3.2433
# Epoch [   14/   15] | d_loss: 0.7351 | g_loss: 2.3399
# Epoch [   14/   15] | d_loss: 0.6051 | g_loss: 2.1968
# Epoch [   14/   15] | d_loss: 0.6491 | g_loss: 2.1486
# Epoch [   14/   15] | d_loss: 0.6170 | g_loss: 3.2450
# Epoch [   14/   15] | d_loss: 0.4685 | g_loss: 2.2180
# Epoch [   14/   15] | d_loss: 0.6745 | g_loss: 4.1647
# Epoch [   14/   15] | d_loss: 0.7697 | g_loss: 2.2287
# Epoch [   14/   15] | d_loss: 0.6051 | g_loss: 3.8238
# Epoch [   14/   15] | d_loss: 0.6062 | g_loss: 2.9644
# Epoch [   14/   15] | d_loss: 0.6187 | g_loss: 2.4225
# Epoch [   14/   15] | d_loss: 0.7527 | g_loss: 2.2260
# Epoch [   14/   15] | d_loss: 0.5385 | g_loss: 2.4771
# Epoch [   14/   15] | d_loss: 0.4716 | g_loss: 2.3405
# Epoch [   14/   15] | d_loss: 0.4586 | g_loss: 3.3669
# Epoch [   14/   15] | d_loss: 0.7356 | g_loss: 1.5846
# Epoch [   14/   15] | d_loss: 0.5870 | g_loss: 2.4309
# Epoch [   14/   15] | d_loss: 0.4925 | g_loss: 2.8181
# Epoch [   14/   15] | d_loss: 0.4679 | g_loss: 3.6519
# Epoch [   14/   15] | d_loss: 0.4541 | g_loss: 3.1450
# Epoch [   14/   15] | d_loss: 0.5059 | g_loss: 2.8287
# Epoch [   14/   15] | d_loss: 0.4920 | g_loss: 3.9924
# Epoch [   14/   15] | d_loss: 0.7047 | g_loss: 3.1702
# Epoch [   14/   15] | d_loss: 0.6347 | g_loss: 2.5724
# Epoch [   14/   15] | d_loss: 0.5494 | g_loss: 2.8607
# Epoch [   14/   15] | d_loss: 0.5059 | g_loss: 2.8672
# Epoch [   14/   15] | d_loss: 0.5675 | g_loss: 2.2988
# Epoch [   14/   15] | d_loss: 0.4438 | g_loss: 3.7393
# Epoch [   14/   15] | d_loss: 0.5302 | g_loss: 2.8992
# Epoch [   14/   15] | d_loss: 0.5535 | g_loss: 3.3979
# Epoch [   15/   15] | d_loss: 0.6384 | g_loss: 2.2981
# Epoch [   15/   15] | d_loss: 0.9734 | g_loss: 2.0240
# Epoch [   15/   15] | d_loss: 0.5595 | g_loss: 2.9981
# Epoch [   15/   15] | d_loss: 0.4473 | g_loss: 3.8345
# Epoch [   15/   15] | d_loss: 0.5701 | g_loss: 2.8262
# Epoch [   15/   15] | d_loss: 0.4961 | g_loss: 3.2082
# Epoch [   15/   15] | d_loss: 0.8843 | g_loss: 1.9829
# Epoch [   15/   15] | d_loss: 1.4791 | g_loss: 3.6207
# Epoch [   15/   15] | d_loss: 0.9725 | g_loss: 2.7922
# Epoch [   15/   15] | d_loss: 0.5191 | g_loss: 2.7721
# Epoch [   15/   15] | d_loss: 0.6071 | g_loss: 2.7583
# Epoch [   15/   15] | d_loss: 0.8960 | g_loss: 2.5418
# Epoch [   15/   15] | d_loss: 0.6913 | g_loss: 2.6557
# Epoch [   15/   15] | d_loss: 0.5551 | g_loss: 3.0681
# Epoch [   15/   15] | d_loss: 0.6742 | g_loss: 1.8135
# Epoch [   15/   15] | d_loss: 1.0687 | g_loss: 2.8746
# Epoch [   15/   15] | d_loss: 0.5210 | g_loss: 3.2662
# Epoch [   15/   15] | d_loss: 0.5324 | g_loss: 2.5758
# Epoch [   15/   15] | d_loss: 0.4535 | g_loss: 3.9111
# Epoch [   15/   15] | d_loss: 0.4212 | g_loss: 4.4275
# Epoch [   15/   15] | d_loss: 0.4686 | g_loss: 2.9497
# Epoch [   15/   15] | d_loss: 1.2431 | g_loss: 3.2445
# Epoch [   15/   15] | d_loss: 0.5232 | g_loss: 2.2690
# Epoch [   15/   15] | d_loss: 0.5800 | g_loss: 3.2228
# Epoch [   15/   15] | d_loss: 0.4834 | g_loss: 3.8510
# Epoch [   15/   15] | d_loss: 0.4845 | g_loss: 3.5751
# Epoch [   15/   15] | d_loss: 0.4614 | g_loss: 3.8360
# Epoch [   15/   15] | d_loss: 0.4545 | g_loss: 3.5318
# Epoch [   15/   15] | d_loss: 0.5779 | g_loss: 3.1555
# Epoch [   15/   15] | d_loss: 0.5488 | g_loss: 2.5923
# Epoch [   15/   15] | d_loss: 0.6034 | g_loss: 2.6022
# Epoch [   15/   15] | d_loss: 0.4739 | g_loss: 2.8265
# Epoch [   15/   15] | d_loss: 0.6439 | g_loss: 2.5417
# Epoch [   15/   15] | d_loss: 0.5693 | g_loss: 3.0302
# Epoch [   15/   15] | d_loss: 0.4403 | g_loss: 3.3984
# Epoch [   15/   15] | d_loss: 0.5996 | g_loss: 3.4179
# Epoch [   15/   15] | d_loss: 0.4622 | g_loss: 3.9838
# Epoch [   15/   15] | d_loss: 0.5230 | g_loss: 3.1377
# Epoch [   15/   15] | d_loss: 0.6408 | g_loss: 3.5408
# Epoch [   15/   15] | d_loss: 0.9735 | g_loss: 1.5213
# Epoch [   15/   15] | d_loss: 0.4073 | g_loss: 3.7791
# Epoch [   15/   15] | d_loss: 0.4332 | g_loss: 2.3970
# Epoch [   15/   15] | d_loss: 0.6234 | g_loss: 3.3843
# Epoch [   15/   15] | d_loss: 0.4523 | g_loss: 2.8964
# Epoch [   15/   15] | d_loss: 0.8092 | g_loss: 1.5232
# Epoch [   15/   15] | d_loss: 0.4640 | g_loss: 2.9994
# Epoch [   15/   15] | d_loss: 0.4600 | g_loss: 4.3351
# Epoch [   15/   15] | d_loss: 0.6840 | g_loss: 2.9886
# Epoch [   15/   15] | d_loss: 0.5629 | g_loss: 2.6464
# Epoch [   15/   15] | d_loss: 0.6300 | g_loss: 2.1886
# Epoch [   15/   15] | d_loss: 0.8809 | g_loss: 3.2522
# Epoch [   15/   15] | d_loss: 0.6239 | g_loss: 3.1400
# Epoch [   15/   15] | d_loss: 0.5471 | g_loss: 3.4306
# Epoch [   15/   15] | d_loss: 0.6309 | g_loss: 3.4391
# Epoch [   15/   15] | d_loss: 0.6316 | g_loss: 2.8132
# Epoch [   15/   15] | d_loss: 0.5249 | g_loss: 3.2565
# Epoch [   15/   15] | d_loss: 0.6988 | g_loss: 3.0919
# Epoch [   15/   15] | d_loss: 0.5796 | g_loss: 3.5638
# Epoch [   15/   15] | d_loss: 0.4596 | g_loss: 3.7617
# Epoch [   15/   15] | d_loss: 0.7473 | g_loss: 1.2900
# Epoch [   15/   15] | d_loss: 0.7228 | g_loss: 2.1439
# Epoch [   15/   15] | d_loss: 0.4636 | g_loss: 3.2840
# Epoch [   15/   15] | d_loss: 0.4479 | g_loss: 3.7734
# Epoch [   15/   15] | d_loss: 0.6776 | g_loss: 1.8110
# Epoch [   15/   15] | d_loss: 0.4817 | g_loss: 2.4037
# Epoch [   15/   15] | d_loss: 0.6232 | g_loss: 2.9207
# Epoch [   15/   15] | d_loss: 0.5188 | g_loss: 3.1215
# Epoch [   15/   15] | d_loss: 0.3925 | g_loss: 3.7536
# Epoch [   15/   15] | d_loss: 0.5708 | g_loss: 2.8524
# Epoch [   15/   15] | d_loss: 0.4130 | g_loss: 3.2789
# Epoch [   15/   15] | d_loss: 0.7583 | g_loss: 2.1170
# Epoch [   15/   15] | d_loss: 0.5463 | g_loss: 3.4915
# Epoch [   15/   15] | d_loss: 0.4358 | g_loss: 2.7494
# Epoch [   15/   15] | d_loss: 0.5624 | g_loss: 3.2470
# Epoch [   15/   15] | d_loss: 0.5714 | g_loss: 1.9725
# Epoch [   15/   15] | d_loss: 0.4760 | g_loss: 3.2521
# Epoch [   15/   15] | d_loss: 0.7691 | g_loss: 2.8390
# Epoch [   15/   15] | d_loss: 0.4182 | g_loss: 3.0628
# Epoch [   15/   15] | d_loss: 0.5579 | g_loss: 2.9669
# Epoch [   15/   15] | d_loss: 0.5267 | g_loss: 1.7429
# Epoch [   15/   15] | d_loss: 0.9601 | g_loss: 2.5983
# Epoch [   15/   15] | d_loss: 0.4728 | g_loss: 3.3558
# Epoch [   15/   15] | d_loss: 0.4901 | g_loss: 3.3037
# Epoch [   15/   15] | d_loss: 0.5003 | g_loss: 2.6452
# Epoch [   15/   15] | d_loss: 0.4023 | g_loss: 4.0204
# Epoch [   15/   15] | d_loss: 0.6591 | g_loss: 3.1402
# Epoch [   15/   15] | d_loss: 0.4285 | g_loss: 3.7734
# Epoch [   15/   15] | d_loss: 0.5699 | g_loss: 2.5302
# Epoch [   15/   15] | d_loss: 0.5128 | g_loss: 2.3150
# Epoch [   15/   15] | d_loss: 0.4829 | g_loss: 3.7971
# Epoch [   15/   15] | d_loss: 0.5104 | g_loss: 2.4861
# Epoch [   15/   15] | d_loss: 0.5959 | g_loss: 2.7421
# Epoch [   15/   15] | d_loss: 0.5539 | g_loss: 3.3565
# Epoch [   15/   15] | d_loss: 0.6781 | g_loss: 3.0179
# Epoch [   15/   15] | d_loss: 0.4380 | g_loss: 3.6049
# Epoch [   15/   15] | d_loss: 0.5155 | g_loss: 3.4682
# Epoch [   15/   15] | d_loss: 0.4863 | g_loss: 3.0834
# Epoch [   15/   15] | d_loss: 0.4868 | g_loss: 3.5487
# Epoch [   15/   15] | d_loss: 0.4167 | g_loss: 3.1766
# Epoch [   15/   15] | d_loss: 0.4114 | g_loss: 4.4775
# Epoch [   15/   15] | d_loss: 0.4784 | g_loss: 2.5775
# Epoch [   15/   15] | d_loss: 0.5343 | g_loss: 2.6828
# Epoch [   15/   15] | d_loss: 0.7613 | g_loss: 2.6806
# Epoch [   15/   15] | d_loss: 0.4474 | g_loss: 3.7645
# Epoch [   15/   15] | d_loss: 0.4713 | g_loss: 3.6428
# Epoch [   15/   15] | d_loss: 0.5349 | g_loss: 1.8955
# Epoch [   15/   15] | d_loss: 0.5245 | g_loss: 2.8011
# Epoch [   15/   15] | d_loss: 0.5248 | g_loss: 3.1716
# Epoch [   15/   15] | d_loss: 0.5030 | g_loss: 2.4628
# Epoch [   15/   15] | d_loss: 0.4992 | g_loss: 3.4012
# Epoch [   15/   15] | d_loss: 0.8485 | g_loss: 2.9026
# Epoch [   15/   15] | d_loss: 0.6277 | g_loss: 2.5436
# Epoch [   15/   15] | d_loss: 0.7698 | g_loss: 2.1064

# %% [markdown]
# ## Training loss
#
# Plot the training losses for the generator and discriminator, recorded after each epoch.

# %%
fig, ax = plt.subplots()
losses = np.array(losses)
plt.plot(losses.T[0], label='Discriminator', alpha=0.5)
plt.plot(losses.T[1], label='Generator', alpha=0.5)
plt.title("Training Losses")
plt.legend()

# %% [markdown]
# ## Generator samples from training
#
# View samples of images from the generator, and answer a question about the strengths and weaknesses of your trained models.

# %%
# helper function for viewing a list of passed in sample images
def view_samples(epoch, samples):
    fig, axes = plt.subplots(figsize=(16,4), nrows=2, ncols=8, sharey=True, sharex=True)
    for ax, img in zip(axes.flatten(), samples[epoch]):
        img = img.detach().cpu().numpy()
        img = np.transpose(img, (1, 2, 0))
        img = ((img + 1)*255 / (2)).astype(np.uint8)
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)
        im = ax.imshow(img.reshape((32,32,3)))

# %%
# Load samples from generator, taken while training
with open('train_samples.pkl', 'rb') as f:
    samples = pkl.load(f)

# %%
_ = view_samples(-1, samples)

# %% [markdown]
# ### Question: What do you notice about your generated samples and how might you improve this model?
# When you answer this question, consider the following factors:
# * The dataset is biased; it is made of "celebrity" faces that are mostly white
# * Model size; larger models have the opportunity to learn more features in a data feature space
# * Optimization strategy; optimizers and number of epochs affect your final result

# %% [markdown]
# **Answer:** </br>
# <br>There are many things that can help to improve the model:
# 1. start with high resolution models will in turn generate higher resolution images
# 2. use different loss function (eg. Wasserstein loss)
# 3. include other races in the input data (debias)
# 4. include res blocks to increase model and also stablize model
# 5. use metrics like inception score to measure model performance

# %% [markdown]
# ### Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_face_generation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "problem_unittests.py" files in your submission.
